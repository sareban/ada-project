# %% [markdown]
# # Artists
#
# Here we will get the genres and origin of the artists.
# We will use the file that contains all the artists who played in Switzerland that comes from the different sources.
#
#
# We will use [Spotify API](https://developer.spotify.com).
#
# Data:
# - artist name
# - artist genre
# - artist origin
# - no_result
# - ambigous_result
#
# If we can't find an artist we will put '1' in the value 'no_result'
# If we find several artists with the same name we will put '1' in the value 'ambigous_result'
#
# Spotify can only specify genres.

# %%
import pandas as pd
import numpy as np
import os
import spotifyHelper as spotifyHelper
import artistsHelper as artistsHelper
import multiprocessing
import time

# %%
df = pd.read_csv('total_artists.csv')
starting_index = 0
df = df.ix[starting_index:]

df1, df2, df3, df4 = spotifyHelper.splitDataFrames(df)

# %%
# Parrallel multiprocessing
num_cores = multiprocessing.cpu_count()
pool = multiprocessing.Pool(num_cores)
start_time = time.time()
p1 = pool.Process(target = spotifyHelper.getDataSpotifyGraph, args=(df1,1))
p1.start()
p2 = pool.Process(target = spotifyHelper.getDataSpotifyGraph, args=(df2,2))
p2.start()
p3 = pool.Process(target = spotifyHelper.getDataSpotifyGraph, args=(df3,3))
p3.start()
p4 = pool.Process(target = spotifyHelper.getDataSpotifyGraph, args=(df4,4))
p4.start()
# Out:
# 61991 / 61999
# 61992 / 61999
# 61993 / 61999
# 61994 / 61999
# 61995 / 61999
# 61996 / 61999
# 61997 / 61999
# 61998 / 61999
# 61999 / 61999
# --- 6685.638111114502 seconds ---

# %%
dfconcat = spotifyHelper.concatDataSpotify()

# %%
dfconcat
# Out:
#        ambigous_result               genre                          name  \
# 0                    1                 NaN                    Colin Dale
# 1                    1                 NaN                  Pino Arduini
# 2                    0          acid house                    Jeff Mills
# 3                    0         disco house                  Paul Van Dyk
# 4                    0        electroclash                       DJ Hell
# 5                    1                 NaN                   Max Durante
# 6                    0         float house                        Willow
# 7                    1                 NaN                       St.Paul
# 8                    0       german techno                 Patrick Zigon
# 9                    1                 NaN                  Oliver Klein
# 10                   1                 NaN                        Ondrej
# 11                   0       bubble trance                       Taucher
# 12                   1                 NaN                       Dubfunk
# 13                   0                 NaN                     Everstone
# 14                   0                 NaN                   Massive Jay
# 15                   0                 NaN                   Groombridge
# 16                   0                 NaN                      Painhead
# 17                   0                 NaN                        shEver
# 18                   0         garage rock                    Mando Diao
# 19                   0   alternative metal                  Foo Fighters
# 20                   1                 NaN           Round Table Knights
# 21                   0  minimal tech house                         Agnès
# 22                   0                 NaN                       Storlon
# 23                   0  minimal tech house                    Mirko Loko
# 24                   0      detroit techno            Ricardo Villalobos
# 25                   0      future ambient                         Volta
# 26                   1                 NaN                    Dandy Jack
# 27                   0  minimal tech house                    Digitaline
# 28                   0       german techno               Guido Schneider
# 29                   1                 NaN                        Jacqui
# ...                ...                 ...                           ...
# 33981                0                 NaN       Riverside Festival 2017
# 33982                0                 NaN      Riverside Festival 2017
# 33983                0         german punk                     Serum 114
# 33984                0                 NaN                Luke Mockridge
# 33985                0                 NaN     Country Night Gstaad 2017
# 33986                1                 NaN                   Tim Allhoff
# 33987                0           aggrotech                    Solar Fake
# 33988                0                 NaN                    Yokko 2017
# 33989                0                 NaN    25 Jahre Marc Pircher 2017
# 33990                0                 NaN           das Palat Orchester
# 33991                0                 NaN       Schupfart Festival 2017
# 33992                0                 NaN                    Bliss 2017
# 33993                0                 NaN             Chippendales 2017
# 33994                0                 NaN          In Der Grossen Halle
# 33995                0                 NaN      Stone Breeze - Tourdates
# 33996                1                 NaN                    Chris Tall
# 33997                0                 NaN  Kappeler Schlagernächte 2017
# 33998                0                 NaN    ONE HEART Worship Day 2017
# 33999                0                 NaN      Irish Folk Festival 2017
# 34000                0                 NaN     Jeanine De Bique, Soprano
# 34001                0                 NaN       SEAT Music Session 2017
# 34002                0                 NaN                    Seven 2017
# 34003                0                 NaN                 Schiller 2017
# 34004                0                 NaN   Benefiz Schlager-Abend 2017
# 34005                0                 NaN          Johannes Oerding2017
# 34006                0                 NaN                 Sonic 27 2017
# 34007                0         fingerstyle                  Calum Graham
# 34008                1                 NaN              Voices of Africa
# 34009                0                 NaN                 Dwight Robson
# 34010                0                 NaN     Original Ländlerweihnacht
#
#        no_result  origin
# 0              0     NaN
# 1              0     NaN
# 2              0     NaN
# 3              0     NaN
# 4              0     NaN
# 5              0     NaN
# 6              0     NaN
# 7              0     NaN
# 8              0     NaN
# 9              0     NaN
# 10             0     NaN
# 11             0     NaN
# 12             0     NaN
# 13             0     NaN
# 14             1     NaN
# 15             0     NaN
# 16             0     NaN
# 17             0     NaN
# 18             0     NaN
# 19             0     NaN
# 20             0     NaN
# 21             0     NaN
# 22             0     NaN
# 23             0     NaN
# 24             0     NaN
# 25             0     NaN
# 26             0     NaN
# 27             0     NaN
# 28             0     NaN
# 29             0     NaN
# ...          ...     ...
# 33981          1     NaN
# 33982          1     NaN
# 33983          0     NaN
# 33984          1     NaN
# 33985          1     NaN
# 33986          0     NaN
# 33987          0     NaN
# 33988          1     NaN
# 33989          1     NaN
# 33990          1     NaN
# 33991          1     NaN
# 33992          1     NaN
# 33993          1     NaN
# 33994          1     NaN
# 33995          1     NaN
# 33996          0     NaN
# 33997          1     NaN
# 33998          1     NaN
# 33999          1     NaN
# 34000          1     NaN
# 34001          1     NaN
# 34002          1     NaN
# 34003          1     NaN
# 34004          1     NaN
# 34005          1     NaN
# 34006          1     NaN
# 34007          0     NaN
# 34008          0     NaN
# 34009          0     NaN
# 34010          1     NaN
#
# [34011 rows x 5 columns]
