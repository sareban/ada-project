# %% [markdown]
# # Artists
#
# Here we will get the genres and origin of the artists.
# We will use the file that contains all the artists who played in Switzerland that comes from the different sources.
#
#
# We will use [Spotify API](https://developer.spotify.com).
#
# Data:
# - artist name
# - artist genre
# - artist origin
# - no_result
# - ambigous_result
#
# If we can't find an artist we will put '1' in the value 'no_result'
# If we find several artists with the same name we will put '1' in the value 'ambigous_result'
#
# Spotify can only specify genres.

# %%
import pandas as pd
import numpy as np
import os
import spotifyHelper as spotifyHelper
import artistsHelper as artistsHelper
import multiprocessing
import time

# %%
df = pd.read_csv('total_artists.csv')
starting_index = 0
df = df.ix[starting_index:]

df1, df2, df3, df4 = spotifyHelper.splitDataFrames(df)

# %%
# Parrallel multiprocessing
num_cores = multiprocessing.cpu_count()
pool = multiprocessing.Pool(num_cores)
start_time = time.time()
p1 = pool.Process(target = spotifyHelper.getDataSpotifyGraph, args=(df1,1))
p1.start()
p2 = pool.Process(target = spotifyHelper.getDataSpotifyGraph, args=(df2,2))
p2.start()
p3 = pool.Process(target = spotifyHelper.getDataSpotifyGraph, args=(df3,3))
p3.start()
p4 = pool.Process(target = spotifyHelper.getDataSpotifyGraph, args=(df4,4))
p4.start()
# Out:
# 0 / 10748
# 10750 / 21497
# 21498 / 32245
# 1 / 10748
# 32247 / 42994

# %%
df = spotifyHelper.concatDataSpotify()
df
# Out:
# file saved
#       ambigous_result               genre  \
# 0                 0.0                Rock
# 1                 0.0                 NaN
# 2                 0.0                 NaN
# 3                 0.0                 Pop
# 4                 0.0   alternative metal
# 5                 0.0                Rock
# 6                 0.0                Rock
# 7                 1.0                 NaN
# 8                 0.0  Comedy/Spoken Word
# 9                 0.0   alternative metal
# 10                1.0                 NaN
# 11                0.0   Electronica/Dance
# 12                1.0                 NaN
# 13                1.0                 NaN
# 14                0.0   Alternative/Indie
# 15                1.0                 NaN
# 16                0.0    crossover thrash
# 17                0.0                Rock
# 18                0.0   Alternative/Indie
# 19                0.0                Jazz
# 20                1.0                 NaN
# 21                0.0                Rock
# 22                1.0                 NaN
# 23                1.0                 NaN
# 24                0.0          german pop
# 25                0.0          german pop
# 26                0.0                 NaN
# 27                0.0   Electronica/Dance
# 28                0.0   Alternative/Indie
# 29                0.0                 NaN
# ...               ...                 ...
# 2074              1.0                 NaN
# 2075              0.0                 NaN
# 2076              0.0                 NaN
# 2077              0.0                 NaN
# 2078              0.0       electro swing
# 2079              0.0                 NaN
# 2080              0.0                 NaN
# 2081              0.0     deep euro house
# 2082              0.0                 NaN
# 2083              0.0         channel pop
# 2084              0.0                 NaN
# 2085              0.0                 NaN
# 2086              0.0                 NaN
# 2087              0.0                 NaN
# 2088              0.0                 NaN
# 2089              0.0                 NaN
# 2090              0.0       italian metal
# 2091              0.0                 NaN
# 2092              0.0                 NaN
# 2093              0.0                 NaN
# 2094              1.0                 NaN
# 2095              0.0   heavy gothic rock
# 2096              0.0                 NaN
# 2097              0.0                 NaN
# 2098              0.0                 NaN
# 2099              0.0                 NaN
# 2100              0.0                 NaN
# 2101              0.0                 NaN
# 2102              0.0     alternative emo
# 2103              0.0                 NaN
#
#                                                    name  no_result  \
# 0                                           Groombridge        0.0
# 1                                              Painhead        0.0
# 2                                                shEver        0.0
# 3                                            Mando Diao        0.0
# 4                                          Foo Fighters        0.0
# 5                                          Heavy Demons        0.0
# 6                                         Reel Big Fish        0.0
# 7                                           Baby Genius        0.0
# 8                                         Henry Rollins        0.0
# 9                                           Linkin Park        0.0
# 10                                             MONTREAL        0.0
# 11                                      Christian Scott        0.0
# 12                                               Hiromi        0.0
# 13                                             Blackout        0.0
# 14                                           Yellowcard        0.0
# 15                                               Avatar        0.0
# 16                                           Holy Moses        0.0
# 17                                             Obituary        0.0
# 18                                         The Peacocks        0.0
# 19                                          Freddy Cole        0.0
# 20                                            NORMANDIE        0.0
# 21                                     From Dying Skies        0.0
# 22                                                 Dimi        0.0
# 23                                               M.I.A.        0.0
# 24                                        Paulsrekorder        0.0
# 25                                                  Mia        0.0
# 26                                         Angelo Kelly        0.0
# 27                                    Matthias Tanzmann        0.0
# 28                                         Tyske Ludder        0.0
# 29                                    HOT RUNNING BLOOD        0.0
# ...                                                 ...        ...
# 2074                                           Meredith        0.0
# 2075                                     Dorsaf Hamdani        0.0
# 2076                                  YOUSSOUPHA THONEX        1.0
# 2077                                              M.A.M        0.0
# 2078                                        Pink Turtle        0.0
# 2079                           CARL COX AT MAD LAUSANNE        1.0
# 2080                                   Passive Movement        1.0
# 2081                                         Ante Perry        0.0
# 2082  SPORTEXPRESS nach Bern WM-Qualifikationsspiel ...        1.0
# 2083                                         Tyler Ward        0.0
# 2084                            verschoben vom 24.02.12        1.0
# 2085         Hommage Al Maestro Luciano Pavarotti BASEL        1.0
# 2086                                  Fred Frith ZÜRICH        1.0
# 2087                                          Roachford        0.0
# 2088                                    BAND FRAUENFELD        1.0
# 2089                                     Davide Arneodo        1.0
# 2090                                       Psychofagist        0.0
# 2091                     rescheduled from 25th Feb 2012        1.0
# 2092                                   Orchester GENÈVE        1.0
# 2093                                          No Square        0.0
# 2094                                               Soen        0.0
# 2095                                         November 7        0.0
# 2096                        GU!ZMO en concert NEUCHÂTEL        1.0
# 2097                                   Emanuele Inglese        0.0
# 2098                                   Tina Dico ZÜRICH        1.0
# 2099                                      local support        1.0
# 2100                            Mister Luzern Wahl 2012        1.0
# 2101                                         Der Mikado        1.0
# 2102                                  Living With Lions        0.0
# 2103                                      Casino Cruise        1.0
#
#                         origin
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                       Sweden
# 4                          NaN
# 5                          NaN
# 6     United States of America
# 7                          NaN
# 8     United States of America
# 9                          NaN
# 10                         NaN
# 11    United States of America
# 12                         NaN
# 13                         NaN
# 14    United States of America
# 15                         NaN
# 16                         NaN
# 17    United States of America
# 18                         NaN
# 19    United States of America
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                     Germany
# 25                         NaN
# 26                       Spain
# 27                     Germany
# 28                     Germany
# 29                         NaN
# ...                        ...
# 2074                       NaN
# 2075                       NaN
# 2076                       NaN
# 2077                       NaN
# 2078                       NaN
# 2079                       NaN
# 2080                       NaN
# 2081                       NaN
# 2082                       NaN
# 2083                       NaN
# 2084                       NaN
# 2085                       NaN
# 2086                       NaN
# 2087                       NaN
# 2088                       NaN
# 2089                       NaN
# 2090                       NaN
# 2091                       NaN
# 2092                       NaN
# 2093                       NaN
# 2094                       NaN
# 2095                       NaN
# 2096                       NaN
# 2097                       NaN
# 2098                       NaN
# 2099                       NaN
# 2100                       NaN
# 2101                       NaN
# 2102                       NaN
# 2103                       NaN
#
# [34209 rows x 5 columns]
