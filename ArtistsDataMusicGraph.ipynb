# %% [markdown]
# # Artists Music Graph
#
#
#
# Here we will get the genres and origin of the artists.
# We will use the file that contains all the artists who played in Switzerland that comes from the different sources.
#
#
# We will use [musicgraph API](http://musicgraph.com/#/home).
# **API KEY is expired as the number of call limit is 5000, and we are over this limit. We should create a new account on the website, and copy the API key in the musicGraphHelper file**
#
# Data:
# - artist name
# - artist genre
# - artist origin
# - no_result
# - ambigous_result
#
# If we can't find an artist we will put '1' in the value 'no_result'
# If we find several artists with the same name we will put '1' in the value 'ambigous_result'

# %%
import pandas as pd
import musicGraphHelper as musicGraphHelper
import bandsInTownHelper as bandsInTownHelper
import csv

# %%
df = pd.read_csv('total_artists.csv', encoding='utf-8', error_bad_lines=False, usecols=[0,1,2,3,4])
df.shape
df = df[:31]

# %%
api_key = '713e1e102705dfd6364b267932879f03'
df_artist_musicgraph = musicGraphHelper.getDataMusicGraph(df, api_key)

# %%
df_artist_musicgraph
# Out:
#    ambigous_result              genre                 name  no_result  \
# 0                0  Electronica/Dance           Colin Dale          0
# 0                0  Electronica/Dance         Pino Arduini          0
# 0                0  Electronica/Dance           Jeff Mills          0
# 0                0  Electronica/Dance         Paul Van Dyk          0
# 0                0  Electronica/Dance              DJ Hell          0
# 0                0  Electronica/Dance          Max Durante          0
# 0                0  Electronica/Dance               Willow          0
# 0                0                NaN              St.Paul          1
# 0                0  Electronica/Dance        Patrick Zigon          0
# 0                0  Electronica/Dance         Oliver Klein          0
# 0                0                NaN               Ondrej          1
# 0                0  Electronica/Dance              Taucher          0
# 0                0                NaN              Dubfunk          1
# 0                0                NaN            Everstone          1
# 0                0                NaN          Massive Jay          1
# 0                0               Rock          Groombridge          0
# 0                0                NaN             Painhead          1
# 0                0                NaN               shEver          0
# 0                0                Pop           Mando Diao          0
# 0                0                NaN         Foo Fighters          1
# 0                0  Electronica/Dance  Round Table Knights          0
# 0                1                NaN                Agnès          1
# 0                1                NaN              Storlon          1
# 0                0  Electronica/Dance           Mirko Loko          0
# 0                0  Electronica/Dance   Ricardo Villalobos          0
# 0                0  electronica/dance                Volta          0
# 0                0                NaN           Dandy Jack          0
# 0                0  Electronica/Dance           Digitaline          0
# 0                0  Electronica/Dance      Guido Schneider          0
# 0                0  Electronica/Dance               Jacqui          0
# 0                0  Electronica/Dance     Stanton Warriors          0
#
#                      origin
# 0                   England
# 0                       NaN
# 0  United States of America
# 0                   Germany
# 0                   Germany
# 0                     Italy
# 0  United States of America
# 0                       NaN
# 0                       NaN
# 0                   Germany
# 0                       NaN
# 0                   Germany
# 0                       NaN
# 0                       NaN
# 0                       NaN
# 0                       NaN
# 0                       NaN
# 0               Switzerland
# 0                    Sweden
# 0                       NaN
# 0               Switzerland
# 0                       NaN
# 0                       NaN
# 0                       NaN
# 0                   Germany
# 0                   Germany
# 0                   Germany
# 0                       NaN
# 0                   Germany
# 0                       NaN
# 0                   England
