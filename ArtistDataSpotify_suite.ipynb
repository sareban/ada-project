# %% [markdown]
# # Artists
#
# This notebook manages a bread of the scrapping. It will start from where it has stopped.
#
# Here we will get the genres and origin of the artists.
# We will use the file that contains all the artists who played in Switzerland that comes from the different sources.
#
#
# We will use [Spotify API](https://developer.spotify.com).
#
# Data:
# - artist name
# - artist genre
# - artist origin
# - no_result
# - ambigous_result
#
# If we can't find an artist we will put '1' in the value 'no_result'
# If we find several artists with the same name we will put '1' in the value 'ambigous_result'
#
# Spotify can only specify genres.

# %%
import pandas as pd
import numpy as np
import os
import spotifyHelper as spotifyHelper
import artistsHelper as artistsHelper
import multiprocessing
import time

# %%
df = pd.read_csv('total_artists.csv')
starting_index = 0
df = df.ix[starting_index:]

df1, df2, df3, df4 = spotifyHelper.splitDataFrames(df)

# %%
df1.reset_index(inplace=True, drop=True)
df2.reset_index(inplace=True, drop=True)
df3.reset_index(inplace=True, drop=True)
df4.reset_index(inplace=True, drop=True)

df_csv1 = pd.read_csv('SpotifyData/total_artists_Spotify1.csv')
df_csv2 = pd.read_csv('SpotifyData/total_artists_Spotify2.csv')
df_csv3 = pd.read_csv('SpotifyData/total_artists_Spotify3.csv')
df_csv4 = pd.read_csv('SpotifyData/total_artists_Spotify4.csv')

df1 = df1[df_csv1.last_valid_index()+1:]
df2 = df2[df_csv2.last_valid_index()+1:]
df3 = df3[df_csv3.last_valid_index()+1:]
df4 = df4[df_csv4.last_valid_index()+1:]

# %%
# Parrallel multiprocessing
num_cores = multiprocessing.cpu_count()
pool = multiprocessing.Pool(num_cores)
start_time = time.time()
p1 = pool.Process(target = spotifyHelper.getDataSpotifyGraph, args=(df1,'1suite'))
p1.start()
p2 = pool.Process(target = spotifyHelper.getDataSpotifyGraph, args=(df2,'2suite'))
p2.start()
p3 = pool.Process(target = spotifyHelper.getDataSpotifyGraph, args=(df3,'3suite'))
p3.start()
p4 = pool.Process(target = spotifyHelper.getDataSpotifyGraph, args=(df4,'4suite'))
p4.start()
# Out:
# 15481 / 15499
# 15482 / 15499
# 15483 / 15499
# 15484 / 15499
# 15485 / 15499
# 15486 / 15499
# 15487 / 15499
# 15488 / 15499
# 15489 / 15499
# 15490 / 15499
# 15491 / 15499
# 15492 / 15499
# 15493 / 15499
# 15494 / 15499
# 15495 / 15499
# 15496 / 15499
# 15497 / 15499
# 15498 / 15499
# 15499 / 15499
# --- 5563.931910037994 seconds ---

# %%
spotifyHelper.concatSameData(1)
spotifyHelper.concatSameData(2)
spotifyHelper.concatSameData(3)
spotifyHelper.concatSameData(4)
# Out:
#        ambigous_result          genre  \
# 0                    0            NaN
# 1                    0            NaN
# 2                    0            NaN
# 3                    0            NaN
# 4                    0            NaN
# 5                    0            NaN
# 6                    0            NaN
# 7                    0            NaN
# 8                    0            NaN
# 9                    0            NaN
# 10                   0            NaN
# 11                   0      acid jazz
# 12                   1            NaN
# 13                   0            NaN
# 14                   0            NaN
# 15                   0            NaN
# 16                   0            NaN
# 17                   0     bass music
# 18                   0            NaN
# 19                   1            NaN
# 20                   0    turkish pop
# 21                   0   garage psych
# 22                   0            NaN
# 23                   0            NaN
# 24                   0            NaN
# 25                   0            NaN
# 26                   0            NaN
# 27                   0            NaN
# 28                   0         comedy
# 29                   0  electro swing
# ...                ...            ...
# 15470                0            NaN
# 15471                0            NaN
# 15472                0    german punk
# 15473                0            NaN
# 15474                0            NaN
# 15475                1            NaN
# 15476                0      aggrotech
# 15477                0            NaN
# 15478                0            NaN
# 15479                0            NaN
# 15480                0            NaN
# 15481                0            NaN
# 15482                0            NaN
# 15483                0            NaN
# 15484                0            NaN
# 15485                1            NaN
# 15486                0            NaN
# 15487                0            NaN
# 15488                0            NaN
# 15489                0            NaN
# 15490                0            NaN
# 15491                0            NaN
# 15492                0            NaN
# 15493                0            NaN
# 15494                0            NaN
# 15495                0            NaN
# 15496                0    fingerstyle
# 15497                1            NaN
# 15498                0            NaN
# 15499                0            NaN
#
#                                                     name  no_result  origin
# 0                              Franziska Hauser and Band          1     NaN
# 1         DJ Johny Holiday, Jeden 1. Donnerstag im Monat          1     NaN
# 2      Philharmonie Baden-Baden, Jasmine Choi (Fl), L...          1     NaN
# 3      Berner Symphonieorchester, Rachel Harnisch (S)...          1     NaN
# 4                                          Olivieri Jazz          1     NaN
# 5      Akku Quintett, Thierry Lüthy (sax), Markus Isc...          1     NaN
# 6              DJs Pazkal, Gesang & Klanglos, Kloë Braun          1     NaN
# 7      Distance, Light & Sky (US/GB/NL/B), Pedro Lehmann          0     NaN
# 8                             Juan Wauters, Fart Fanfare          1     NaN
# 9                 My Name Is George, Support: James Gold          1     NaN
# 10                                          Scud the Hog          1     NaN
# 11                                           Speedometer          0     NaN
# 12                                               Nazaire          0     NaN
# 13                                              Baby Val          1     NaN
# 14                                          David Suivez          1     NaN
# 15                                                 Mi-An          1     NaN
# 16                                            bischoff62          1     NaN
# 17                                              Distance          0     NaN
# 18                                                DJ OzO          0     NaN
# 19                                            Young Trap          0     NaN
# 20                                            Helldorado          0     NaN
# 21                                          Juan Wauters          0     NaN
# 22     le digital rencontre Le vinyl pour un mélange ...          1     NaN
# 23                                         cette semaine          1     NaN
# 24     Viens taper du pied sur des rythmes électro et...          1     NaN
# 25     Entre habitudes et nouveautés la programmation...          1     NaN
# 26                                            Vinyl Only          1     NaN
# 27                                       Tedi B2B Bigraf          1     NaN
# 28                                          Eddie Izzard          0     NaN
# 29                                             Degiheugi          0     NaN
# ...                                                  ...        ...     ...
# 15470                            Riverside Festival 2017          1     NaN
# 15471                           Riverside Festival 2017           1     NaN
# 15472                                          Serum 114          0     NaN
# 15473                                     Luke Mockridge          1     NaN
# 15474                          Country Night Gstaad 2017          1     NaN
# 15475                                        Tim Allhoff          0     NaN
# 15476                                         Solar Fake          0     NaN
# 15477                                         Yokko 2017          1     NaN
# 15478                         25 Jahre Marc Pircher 2017          1     NaN
# 15479                                das Palat Orchester          1     NaN
# 15480                            Schupfart Festival 2017          1     NaN
# 15481                                         Bliss 2017          1     NaN
# 15482                                  Chippendales 2017          1     NaN
# 15483                               In Der Grossen Halle          1     NaN
# 15484                           Stone Breeze - Tourdates          1     NaN
# 15485                                         Chris Tall          0     NaN
# 15486                       Kappeler Schlagernächte 2017          1     NaN
# 15487                         ONE HEART Worship Day 2017          1     NaN
# 15488                           Irish Folk Festival 2017          1     NaN
# 15489                          Jeanine De Bique, Soprano          1     NaN
# 15490                            SEAT Music Session 2017          1     NaN
# 15491                                         Seven 2017          1     NaN
# 15492                                      Schiller 2017          1     NaN
# 15493                        Benefiz Schlager-Abend 2017          1     NaN
# 15494                               Johannes Oerding2017          1     NaN
# 15495                                      Sonic 27 2017          1     NaN
# 15496                                       Calum Graham          0     NaN
# 15497                                   Voices of Africa          0     NaN
# 15498                                      Dwight Robson          0     NaN
# 15499                          Original Ländlerweihnacht          1     NaN
#
# [15500 rows x 5 columns]

# %% [markdown]
# ** Delete files '\*1suite', '\*2suite.csv','\*3suite.csv','\*4suite.csv' ** They are now merged into files 1,2,3,4
# Then do the concat

# %%
dfconcat = spotifyHelper.concatDataSpotify()

# %%
dfconcat
# Out:
#        ambigous_result               genre                          name  \
# 0                    1                 NaN                    Colin Dale
# 1                    1                 NaN                  Pino Arduini
# 2                    0          acid house                    Jeff Mills
# 3                    0         disco house                  Paul Van Dyk
# 4                    0        electroclash                       DJ Hell
# 5                    1                 NaN                   Max Durante
# 6                    0         float house                        Willow
# 7                    1                 NaN                       St.Paul
# 8                    0       german techno                 Patrick Zigon
# 9                    1                 NaN                  Oliver Klein
# 10                   1                 NaN                        Ondrej
# 11                   0       bubble trance                       Taucher
# 12                   1                 NaN                       Dubfunk
# 13                   0                 NaN                     Everstone
# 14                   0                 NaN                   Massive Jay
# 15                   0                 NaN                   Groombridge
# 16                   0                 NaN                      Painhead
# 17                   0                 NaN                        shEver
# 18                   0         garage rock                    Mando Diao
# 19                   0   alternative metal                  Foo Fighters
# 20                   1                 NaN           Round Table Knights
# 21                   0  minimal tech house                         Agnès
# 22                   0                 NaN                       Storlon
# 23                   0  minimal tech house                    Mirko Loko
# 24                   0      detroit techno            Ricardo Villalobos
# 25                   0      future ambient                         Volta
# 26                   1                 NaN                    Dandy Jack
# 27                   0  minimal tech house                    Digitaline
# 28                   0       german techno               Guido Schneider
# 29                   1                 NaN                        Jacqui
# ...                ...                 ...                           ...
# 61970                0                 NaN       Riverside Festival 2017
# 61971                0                 NaN      Riverside Festival 2017
# 61972                0         german punk                     Serum 114
# 61973                0                 NaN                Luke Mockridge
# 61974                0                 NaN     Country Night Gstaad 2017
# 61975                1                 NaN                   Tim Allhoff
# 61976                0           aggrotech                    Solar Fake
# 61977                0                 NaN                    Yokko 2017
# 61978                0                 NaN    25 Jahre Marc Pircher 2017
# 61979                0                 NaN           das Palat Orchester
# 61980                0                 NaN       Schupfart Festival 2017
# 61981                0                 NaN                    Bliss 2017
# 61982                0                 NaN             Chippendales 2017
# 61983                0                 NaN          In Der Grossen Halle
# 61984                0                 NaN      Stone Breeze - Tourdates
# 61985                1                 NaN                    Chris Tall
# 61986                0                 NaN  Kappeler Schlagernächte 2017
# 61987                0                 NaN    ONE HEART Worship Day 2017
# 61988                0                 NaN      Irish Folk Festival 2017
# 61989                0                 NaN     Jeanine De Bique, Soprano
# 61990                0                 NaN       SEAT Music Session 2017
# 61991                0                 NaN                    Seven 2017
# 61992                0                 NaN                 Schiller 2017
# 61993                0                 NaN   Benefiz Schlager-Abend 2017
# 61994                0                 NaN          Johannes Oerding2017
# 61995                0                 NaN                 Sonic 27 2017
# 61996                0         fingerstyle                  Calum Graham
# 61997                1                 NaN              Voices of Africa
# 61998                0                 NaN                 Dwight Robson
# 61999                0                 NaN     Original Ländlerweihnacht
#
#        no_result  origin
# 0              0     NaN
# 1              0     NaN
# 2              0     NaN
# 3              0     NaN
# 4              0     NaN
# 5              0     NaN
# 6              0     NaN
# 7              0     NaN
# 8              0     NaN
# 9              0     NaN
# 10             0     NaN
# 11             0     NaN
# 12             0     NaN
# 13             0     NaN
# 14             1     NaN
# 15             0     NaN
# 16             0     NaN
# 17             0     NaN
# 18             0     NaN
# 19             0     NaN
# 20             0     NaN
# 21             0     NaN
# 22             0     NaN
# 23             0     NaN
# 24             0     NaN
# 25             0     NaN
# 26             0     NaN
# 27             0     NaN
# 28             0     NaN
# 29             0     NaN
# ...          ...     ...
# 61970          1     NaN
# 61971          1     NaN
# 61972          0     NaN
# 61973          1     NaN
# 61974          1     NaN
# 61975          0     NaN
# 61976          0     NaN
# 61977          1     NaN
# 61978          1     NaN
# 61979          1     NaN
# 61980          1     NaN
# 61981          1     NaN
# 61982          1     NaN
# 61983          1     NaN
# 61984          1     NaN
# 61985          0     NaN
# 61986          1     NaN
# 61987          1     NaN
# 61988          1     NaN
# 61989          1     NaN
# 61990          1     NaN
# 61991          1     NaN
# 61992          1     NaN
# 61993          1     NaN
# 61994          1     NaN
# 61995          1     NaN
# 61996          0     NaN
# 61997          0     NaN
# 61998          0     NaN
# 61999          1     NaN
#
# [62000 rows x 5 columns]
