# %% [markdown]
# # Artists Music Graph
#
# This notebook manages a stop in the process of scrapping data from musicgraph. It starts the scrapping from where it was stopped.
#
#
#
# Here we will get the genres and origin of the artists.
# We will use the file that contains all the artists who played in Switzerland that comes from the different sources.
#
#
# We will use [musicgraph API](http://musicgraph.com/#/home).
# **API KEY is expired as the number of call limit is 5000, and we are over this limit. We should create a new account on the website, and copy the API key in the musicGraphHelper file**
#
# Data:
# - artist name
# - artist genre
# - artist origin
# - no_result
# - ambigous_result
#
# If we can't find an artist we will put '1' in the value 'no_result'
# If we find several artists with the same name we will put '1' in the value 'ambigous_result'

# %%
import pandas as pd
import musicGraphHelper as musicGraphHelper
import csv
import multiprocessing
import time

# %%
df = pd.read_csv('total_artists.csv', encoding='utf-8', error_bad_lines=False, usecols=[0,1,2,3,4])
starting_index = 0
df = df.ix[starting_index:]

df1, df2, df3, df4 = musicGraphHelper.splitDataFrames(df)

# %%
df1.reset_index(inplace=True, drop=True)
df2.reset_index(inplace=True, drop=True)
df3.reset_index(inplace=True, drop=True)
df4.reset_index(inplace=True, drop=True)

df_csv1 = pd.read_csv('MusicGraphArtistsData/total_artists_MusicGraph1.csv')
df_csv2 = pd.read_csv('MusicGraphArtistsData/total_artists_MusicGraph2.csv')
df_csv3 = pd.read_csv('MusicGraphArtistsData/total_artists_MusicGraph3.csv')
df_csv4 = pd.read_csv('MusicGraphArtistsData/total_artists_MusicGraph4.csv')

df1 = df1[df_csv1.last_valid_index()+1:]
df2 = df2[df_csv2.last_valid_index()+1:]
df3 = df3[df_csv3.last_valid_index()+1:]
df4 = df4[df_csv4.last_valid_index()+1:]

# %% [markdown]
# List of all the API key that we created to face the issue of the 5K calls limits:

# %%
api_key_1 = [
    '2efa0e96a07f76e210dfb1b76f0ad693',
    '8da1bf7fa3f85dd98906d37501c7c5d7',
    'acdd2e62e524849f1927b5e2dee0eeec'
]
api_key_2 = [
    'ca8b86800921d477ce88875a062580d9',
    '6bce7980d78d29f4cfa87f87ad32e8ad'
]
api_key_3 = [
    'acdd2e62e524849f1927b5e2dee0eeec',
    'd6712aaf34a0e11c08df82fe7a2b7d46', 
    '41bdbdbd486e7fc1359b091c47892964'
]
api_key_4 = [
    '3a99445bb8370f2c6b46a3d85d91cd89',
    '28eb166000d2b4518e4b20215e00ce52',
    '3f758e74bf7c3a5b794d5b0d23c1e0bb'
]

# %%
# Parrallel multiprocessing
num_cores = multiprocessing.cpu_count()
pool = multiprocessing.Pool(num_cores)
start_time = time.time()
p1 = pool.Process(target = musicGraphHelper.getDataMusicGraph, args=(df1,'1suite', api_key_1))
p1.start()
p2 = pool.Process(target = musicGraphHelper.getDataMusicGraph, args=(df2,'2suite', api_key_2))
p2.start()
p3 = pool.Process(target = musicGraphHelper.getDataMusicGraph, args=(df3,'3suite', api_key_3))
p3.start()
p4 = pool.Process(target = musicGraphHelper.getDataMusicGraph, args=(df4,'4suite', api_key_4))
p4.start()
# Out:
# 15481 / 15499
# 15482 / 15499
# 15483 / 15499
# 15484 / 15499
# 15485 / 15499
# 15486 / 15499
# 15487 / 15499
# 15488 / 15499
# 15489 / 15499
# 15490 / 15499
# 15491 / 15499
# 15492 / 15499
# 15493 / 15499
# 15494 / 15499
# 15495 / 15499
# 15496 / 15499
# 15497 / 15499
# 15498 / 15499
# 15499 / 15499

# %%
musicGraphHelper.concatSameData(1)
musicGraphHelper.concatSameData(2)
musicGraphHelper.concatSameData(3)
musicGraphHelper.concatSameData(4)
# Out:
#        ambigous_result               genre  \
# 0                    0                 NaN
# 1                    0                 NaN
# 2                    0                 NaN
# 3                    0                 NaN
# 4                    0                 NaN
# 5                    0                 NaN
# 6                    0                 NaN
# 7                    0                 NaN
# 8                    0                 NaN
# 9                    0                 NaN
# 10                   0                 NaN
# 11                   0            Soul/R&B
# 12                   0               Blues
# 13                   0                 NaN
# 14                   0                 NaN
# 15                   0                 NaN
# 16                   0                 NaN
# 17                   0   electronica/dance
# 18                   0                 NaN
# 19                   1                 NaN
# 20                   0                Rock
# 21                   0   Alternative/Indie
# 22                   0                 NaN
# 23                   0                 NaN
# 24                   0                 NaN
# 25                   0                 NaN
# 26                   0                 NaN
# 27                   0                 NaN
# 28                   0  Comedy/Spoken Word
# 29                   1                 NaN
# ...                ...                 ...
# 15470                0                 NaN
# 15471                0                 NaN
# 15472                0                Rock
# 15473                0                 NaN
# 15474                0                 NaN
# 15475                1                 NaN
# 15476                0   Electronica/Dance
# 15477                0                 NaN
# 15478                0                 NaN
# 15479                0                 NaN
# 15480                0                 NaN
# 15481                0                 NaN
# 15482                0                 NaN
# 15483                0                 NaN
# 15484                0                 NaN
# 15485                0                 NaN
# 15486                0                 NaN
# 15487                0                 NaN
# 15488                0                 NaN
# 15489                0                 NaN
# 15490                0                 NaN
# 15491                0                 NaN
# 15492                0                 NaN
# 15493                0                 NaN
# 15494                0                 NaN
# 15495                0                 NaN
# 15496                0                Folk
# 15497                0                 NaN
# 15498                0                 NaN
# 15499                0                 NaN
#
#                                                     name  no_result  \
# 0                              Franziska Hauser and Band          1
# 1         DJ Johny Holiday, Jeden 1. Donnerstag im Monat          1
# 2      Philharmonie Baden-Baden, Jasmine Choi (Fl), L...          1
# 3      Berner Symphonieorchester, Rachel Harnisch (S)...          1
# 4                                          Olivieri Jazz          1
# 5      Akku Quintett, Thierry Lüthy (sax), Markus Isc...          1
# 6              DJs Pazkal, Gesang & Klanglos, Kloë Braun          1
# 7      Distance, Light & Sky (US/GB/NL/B), Pedro Lehmann          1
# 8                             Juan Wauters, Fart Fanfare          1
# 9                 My Name Is George, Support: James Gold          1
# 10                                          Scud the Hog          1
# 11                                           Speedometer          0
# 12                                               Nazaire          0
# 13                                              Baby Val          1
# 14                                          David Suivez          1
# 15                                                 Mi-An          1
# 16                                            bischoff62          1
# 17                                              Distance          0
# 18                                                DJ OzO          1
# 19                                            Young Trap          1
# 20                                            Helldorado          0
# 21                                          Juan Wauters          0
# 22     le digital rencontre Le vinyl pour un mélange ...          1
# 23                                         cette semaine          1
# 24     Viens taper du pied sur des rythmes électro et...          1
# 25     Entre habitudes et nouveautés la programmation...          1
# 26                                            Vinyl Only          1
# 27                                       Tedi B2B Bigraf          1
# 28                                          Eddie Izzard          0
# 29                                             Degiheugi          1
# ...                                                  ...        ...
# 15470                            Riverside Festival 2017          1
# 15471                           Riverside Festival 2017           1
# 15472                                          Serum 114          0
# 15473                                     Luke Mockridge          1
# 15474                          Country Night Gstaad 2017          1
# 15475                                        Tim Allhoff          1
# 15476                                         Solar Fake          0
# 15477                                         Yokko 2017          1
# 15478                         25 Jahre Marc Pircher 2017          1
# 15479                                das Palat Orchester          1
# 15480                            Schupfart Festival 2017          1
# 15481                                         Bliss 2017          1
# 15482                                  Chippendales 2017          1
# 15483                               In Der Grossen Halle          1
# 15484                           Stone Breeze - Tourdates          1
# 15485                                         Chris Tall          1
# 15486                       Kappeler Schlagernächte 2017          1
# 15487                         ONE HEART Worship Day 2017          1
# 15488                           Irish Folk Festival 2017          1
# 15489                          Jeanine De Bique, Soprano          1
# 15490                            SEAT Music Session 2017          1
# 15491                                         Seven 2017          1
# 15492                                      Schiller 2017          1
# 15493                        Benefiz Schlager-Abend 2017          1
# 15494                               Johannes Oerding2017          1
# 15495                                      Sonic 27 2017          1
# 15496                                       Calum Graham          0
# 15497                                   Voices of Africa          0
# 15498                                      Dwight Robson          1
# 15499                          Original Ländlerweihnacht          1
#
#                          origin
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                        Japan
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                      Finland
# 18                          NaN
# 19                          NaN
# 20                       Norway
# 21     United States of America
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                          NaN
# 27                          NaN
# 28                      England
# 29                          NaN
# ...                         ...
# 15470                       NaN
# 15471                       NaN
# 15472                   Germany
# 15473                       NaN
# 15474                       NaN
# 15475                       NaN
# 15476                   Germany
# 15477                       NaN
# 15478                       NaN
# 15479                       NaN
# 15480                       NaN
# 15481                       NaN
# 15482                       NaN
# 15483                       NaN
# 15484                       NaN
# 15485                       NaN
# 15486                       NaN
# 15487                       NaN
# 15488                       NaN
# 15489                       NaN
# 15490                       NaN
# 15491                       NaN
# 15492                       NaN
# 15493                       NaN
# 15494                       NaN
# 15495                       NaN
# 15496                       NaN
# 15497              South Africa
# 15498                       NaN
# 15499                       NaN
#
# [15500 rows x 5 columns]

# %% [markdown]
# ** Delete files '\*1suite', '\*2suite.csv','\*3suite.csv','\*4suite.csv' ** They are now merged into files 1,2,3,4
# Then do the concat

# %%
dfconcat = musicGraphHelper.concatDataMusicGraph()
dfconcat
# Out:
# file saved
#        ambigous_result              genre                          name  \
# 0                    0  Electronica/Dance                    Colin Dale
# 1                    0  Electronica/Dance                  Pino Arduini
# 2                    0  Electronica/Dance                    Jeff Mills
# 3                    0  Electronica/Dance                  Paul Van Dyk
# 4                    0  Electronica/Dance                       DJ Hell
# 5                    0  Electronica/Dance                   Max Durante
# 6                    0  Electronica/Dance                        Willow
# 7                    0                NaN                       St.Paul
# 8                    0  Electronica/Dance                 Patrick Zigon
# 9                    0  Electronica/Dance                  Oliver Klein
# 10                   0                NaN                        Ondrej
# 11                   0  Electronica/Dance                       Taucher
# 12                   0                NaN                       Dubfunk
# 13                   0                NaN                     Everstone
# 14                   0                NaN                   Massive Jay
# 15                   0               Rock                   Groombridge
# 16                   0                NaN                      Painhead
# 17                   0                NaN                        shEver
# 18                   0                Pop                    Mando Diao
# 19                   0                NaN                  Foo Fighters
# 20                   0  Electronica/Dance           Round Table Knights
# 21                   1                NaN                         Agnès
# 22                   1                NaN                       Storlon
# 23                   0  Electronica/Dance                    Mirko Loko
# 24                   0  Electronica/Dance            Ricardo Villalobos
# 25                   0  electronica/dance                         Volta
# 26                   0                NaN                    Dandy Jack
# 27                   0  Electronica/Dance                    Digitaline
# 28                   0  Electronica/Dance               Guido Schneider
# 29                   0  Electronica/Dance                        Jacqui
# ...                ...                ...                           ...
# 61970                0                NaN       Riverside Festival 2017
# 61971                0                NaN      Riverside Festival 2017
# 61972                0               Rock                     Serum 114
# 61973                0                NaN                Luke Mockridge
# 61974                0                NaN     Country Night Gstaad 2017
# 61975                1                NaN                   Tim Allhoff
# 61976                0  Electronica/Dance                    Solar Fake
# 61977                0                NaN                    Yokko 2017
# 61978                0                NaN    25 Jahre Marc Pircher 2017
# 61979                0                NaN           das Palat Orchester
# 61980                0                NaN       Schupfart Festival 2017
# 61981                0                NaN                    Bliss 2017
# 61982                0                NaN             Chippendales 2017
# 61983                0                NaN          In Der Grossen Halle
# 61984                0                NaN      Stone Breeze - Tourdates
# 61985                0                NaN                    Chris Tall
# 61986                0                NaN  Kappeler Schlagernächte 2017
# 61987                0                NaN    ONE HEART Worship Day 2017
# 61988                0                NaN      Irish Folk Festival 2017
# 61989                0                NaN     Jeanine De Bique, Soprano
# 61990                0                NaN       SEAT Music Session 2017
# 61991                0                NaN                    Seven 2017
# 61992                0                NaN                 Schiller 2017
# 61993                0                NaN   Benefiz Schlager-Abend 2017
# 61994                0                NaN          Johannes Oerding2017
# 61995                0                NaN                 Sonic 27 2017
# 61996                0               Folk                  Calum Graham
# 61997                0                NaN              Voices of Africa
# 61998                0                NaN                 Dwight Robson
# 61999                0                NaN     Original Ländlerweihnacht
#
#        no_result                    origin
# 0              0                   England
# 1              0                       NaN
# 2              0  United States of America
# 3              0                   Germany
# 4              0                   Germany
# 5              0                     Italy
# 6              0  United States of America
# 7              1                       NaN
# 8              0                       NaN
# 9              0                   Germany
# 10             1                       NaN
# 11             0                   Germany
# 12             1                       NaN
# 13             1                       NaN
# 14             1                       NaN
# 15             0                       NaN
# 16             1                       NaN
# 17             0               Switzerland
# 18             0                    Sweden
# 19             1                       NaN
# 20             0               Switzerland
# 21             1                       NaN
# 22             1                       NaN
# 23             0                       NaN
# 24             0                   Germany
# 25             0                   Germany
# 26             0                   Germany
# 27             0                       NaN
# 28             0                   Germany
# 29             0                       NaN
# ...          ...                       ...
# 61970          1                       NaN
# 61971          1                       NaN
# 61972          0                   Germany
# 61973          1                       NaN
# 61974          1                       NaN
# 61975          1                       NaN
# 61976          0                   Germany
# 61977          1                       NaN
# 61978          1                       NaN
# 61979          1                       NaN
# 61980          1                       NaN
# 61981          1                       NaN
# 61982          1                       NaN
# 61983          1                       NaN
# 61984          1                       NaN
# 61985          1                       NaN
# 61986          1                       NaN
# 61987          1                       NaN
# 61988          1                       NaN
# 61989          1                       NaN
# 61990          1                       NaN
# 61991          1                       NaN
# 61992          1                       NaN
# 61993          1                       NaN
# 61994          1                       NaN
# 61995          1                       NaN
# 61996          0                       NaN
# 61997          0              South Africa
# 61998          1                       NaN
# 61999          1                       NaN
#
# [62000 rows x 5 columns]
