# %% [markdown]
# # Preprocessing pipeline
# In this notebook, we will clean and agglomerate the data acquired from several platforms to be used conveniently for analysis.

# %%
import pandas as pd
import os
import glob
import urllib
import requests
import time
import json
from pandas.io.json import json_normalize
from IPython.display import clear_output
import numpy as np
import bandsInTownHelper as bandsInTownHelper

# %%
#Load the total_x events data into several DataFrame.

total_eventsch = pd.read_csv(os.path.join('./total_eventsch.csv'))
total_bands_in_town = pd.read_csv(os.path.join('./total_bands_in_town.csv'))
total_residentadvisor = pd.read_csv(os.path.join('./total_residentadvisor.csv'))
total_routedesfestivals = pd.read_csv(os.path.join('./total_routedesfestivals.csv'))

# %% [markdown]
# ### Unifying the representation
# The data gathered on several platforms came in a handful of shapes that we should now normalize while retaining as much information. We will discards platforms only'ids.

# %%
total_bands_in_town.drop(['artist_url', 'event_id', 'event_url', 'event_venue.region', 'event_venue.url', 'event_venue.id'], 1, inplace=True)

#Convert time column to datetime objects
total_bands_in_town['event_datetime'] = pd.to_datetime(total_bands_in_town['event_datetime'])
#Remove time from dates
total_bands_in_town['event_datetime'] = total_bands_in_town['event_datetime'].apply( lambda x: x.date() )
total_bands_in_town.head(10)
# Out:
#     artist_name event_datetime       event_venue.city  event_venue.latitude  \
# 0   Groombridge     2006-01-06             Langenthal             47.212060
# 1      Painhead     2006-01-07              Rorschach             47.477928
# 2        shEver     2006-01-14                    Zug             47.182220
# 3      Painhead     2006-01-15  Gossau (Sankt Gallen)             47.414415
# 4    Mando Diao     2006-01-21                   Laax             46.800000
# 5  Foo Fighters     2006-01-25             Winterthur             47.495655
# 6   Groombridge     2006-01-27               Burgdorf             47.050000
# 7   Groombridge     2007-01-01                  Berne             46.948432
# 8      Painhead     2007-01-06                Sommeri             47.566667
# 9        shEver     2007-01-13                 Zurich             47.386620
#
#    event_venue.longitude              event_venue.name
# 0               7.789998                Rock in Church
# 1               9.495190                   Hafenbuffet
# 2               8.520760                  Industrie 45
# 3               9.254950                    The Office
# 4               9.250000  PALACE CLUB AT RIDERS PALACE
# 5               8.748480              Eishalle Duetwag
# 6               7.616667                      Gymfest
# 7               7.440461                           ONO
# 8               9.283333                    Löwenarena
# 9               8.534380                        Werk21

# %% [markdown]
# ### Venues location
# Bands in Town data associates coordinates to each venue, which could be interesting for representing our findings on maps. We will extract those in a separate DataFrame, and then drop the coordinates from the events DataFrame. For simplicity, we will leave in the venue and city columns.

# %%
#Surely, better to drop following coordinates, as venue names are not cleaned (sometimes venue name is X @ Y)
venues = total_bands_in_town[['event_venue.name', 'event_venue.city', 'event_venue.latitude', 'event_venue.longitude']].copy()
total_bands_in_town.drop(['event_venue.latitude', 'event_venue.longitude'], 1, inplace=True)
venues.drop_duplicates(subset=['event_venue.longitude', 'event_venue.latitude'], inplace=True)
venues.drop_duplicates('event_venue.name', inplace=True)
venues.set_index('event_venue.name', drop=True, append=False, inplace=True)
del venues.index.name
venues = venues.sort_index()

# %%
venues_ra = total_residentadvisor[['club_name', 'club_adress']].copy()
venues_ra.drop_duplicates('club_name', inplace=True)
venues_ra.set_index('club_name', drop=True, append=False, inplace=True)
del venues_ra.index.name
venues_ra
# Out:
#                                                                                  club_adress
#  2. Akt Restaurant & Bar                                                     Selnaustrasse 2
#  25 Hours Hotel Zürich                                   Pfingstweidstrasse 102, 8005 Zürich
#  2B Lounge                                                  Nüschelerstrasse 31, 8001 Zürich
#  3monkeys                                      Alexander-Schönistrasse 17, 2502, Biel/Bienne
#  4. Akt                                                     Heinrichstrasse 262, 8005 Zürich
#  5ème Etage                                                             Mühlenplatz 11, Bern
#  Abraxas                                                      Chemin du Stand 5; Pully, 1009
#  Acanto                                                    Pfingstweidstrasse 6, 8005 Zürich
#  Acapella Bar                                   Place de la Gare, 1957 Ardon, Valais, Suisse
#  Acqua Lounge Basilea                                       Binningerstrasse 14; 4051, Basel
#  Adagio                                                     Seidenhofstrasse 5; 6002, Luzern
#  Akt                                                       Niederdorfstrasse 64, 8001 Zürich
#  Albani Music Club                                                         Steinberggasse 16
#  Alhambar                                              Rue de la Rôtisserie 10; 1204, Genève
#  Alice Choo                                                   Limmatstrasse 275, 8005 Zürich
#  Alte Cigarettenfabrik                                            Sihlquai 268; 8005, Zürich
#  Alte Kaserne                                                  Kanonengasse 16; 8004, Zürich
#  Amboss Rampe                                                    Zollstrasse 80, 8005 Zürich
#  Ancienne Gare Café                              Esplanade de l'ancienne gare, 1700 Fribourg
#  Anciens Abattoirs                         Rue du Commerce 122, 2300 La Chaux-de-Fonds, S...
#  Annex & Kuppel Basel                                                    Binningerstrasse 14
#  Apawi Pure Lounge                                                  Rheingasse 8, 4058 Basel
#  Archiv                                                     Lehenmattstrasse 353, 4052 Basel
#  Arena Mendrisio                                    Via Angelo Maspoli, 24 CH-6850 Mendrisio
#  Athome Club                                            Rue Henry-Grandjean 1, 2400 Le Locle
#  Atlantis Club                                                   Klosterberg 13; 4051, Basel
#  Aura                                                             Bleicherweg 5, 8001 Zürich
#  B'eat                                          Im Alten Riet 22, 9494 Schaan, Liechtenstein
#  B-Side Club                                                  Via Carlo Pasta 2 6830 Chiasso
#  Babette Club                                                   Langstrasse 83, 8004, Zurich
# ...                                                                                      ...
#  Vior                                                            Löwenstrasse 2, 8001 Zürich
#  Viscose Eventbar                                                  Emmenweidstrasse 20, 6020
#  Vogue Club                                                 Rue St. Martin 9, 1003, Lausanne
#  Volkshaus Basel                                                     Rebgasse 12, 4058 Basel
#  Volkshaus Solothurn                                          Rossmarktpl. 2, 4500 Solothurn
#  Volkshaus Zürich                                        Stauffacherstrasse 60; 8004, Zürich
#  VSD                                               Rue de la place d'armes 13, 2114 Fleurier
#  Wasserwerk Club                                              Wasserwerkgasse 5; 3011, Berne
#  Watergate                                       Avenue E.-Jaques Dalcroze 9; 1007, Lausanne
#  Weetamix                                  Chemin Jacques Philibert de Sauvage 37; 1219, ...
#  Westend                                                   Förlibuckstrasse 180, 8005 Zürich
#  WKND                                                             Via Trevano 56 6900 Lugano
#  Wohnzimmer                                                      Rathausgasse 63; 3011, Bern
#  Wohnzimmerbar                                             Kalkbreitestrasse 10, 8003 Zürich
#  X-Tra                                                       Limmatstrasse 118; 8031, Zürich
#  Xces                                                         Albulastrasse 40; 8048, Zurich
#  Xellent Club                                            Rue Centrale 17, 3963 Crans-Montana
#  Xxème                                                       Av. de Tivoli 3; 1700, Fribourg
#  Yakabar                                                    Avenue de la Gare 28; 1950, Sion
#  You Coffee Bar                                               Nordstrasse 14, 4665 Oftringen
#  Yourunivers Club                                            Tannwaldstrasse 101, 4600 Olten
#  Zanzibar                                                     Zentralstrasse 36, 5610 Wohlen
#  Zapoff                                                     Rue de la Vigie 5, 1003 Lausanne
#  Zen'Kâ                                                      Rue de Genève 10, 1003 Lausanne
#  Zerodix                                         3963, Route des Téléphériques 32, 3963 Lens
#  Zoo                                                   Place des Volontaires 4; 1204, Genève
#  ZuDir                                                            Theaterplatz 2, 5400 Baden
#  Zukunft                                                      Dienerstrasse 33; 8004, Zürich
#  Zwingliplatz                                                        Zwinglipl., 8001 Zürich
#  École Polytechnique Fédérale de Lausanne                     Route Cantonale, 1015 Lausanne
#
# [605 rows x 1 columns]

# %%
venues_total = pd.concat([venues, venues_ra])
#for i in venues.index :
#    print(i)
    #if i in venues_ra.index :

# %%
total_bands_in_town.columns = ['Artist', 'Date', 'City', 'Venue']
total_bands_in_town
# Out:
#                                       Artist        Date  \
# 0                                Groombridge  2006-01-06
# 1                                   Painhead  2006-01-07
# 2                                     shEver  2006-01-14
# 3                                   Painhead  2006-01-15
# 4                                 Mando Diao  2006-01-21
# 5                               Foo Fighters  2006-01-25
# 6                                Groombridge  2006-01-27
# 7                                Groombridge  2007-01-01
# 8                                   Painhead  2007-01-06
# 9                                     shEver  2007-01-13
# 10                              Heavy Demons  2007-01-27
# 11                             Reel Big Fish  2008-01-11
# 12                             Reel Big Fish  2008-01-12
# 13                               Baby Genius  2008-01-12
# 14                             Henry Rollins  2008-01-17
# 15                               Linkin Park  2008-01-18
# 16                                  MONTREAL  2008-01-18
# 17                           Christian Scott  2008-01-20
# 18                                    Hiromi  2008-01-22
# 19                                    Hiromi  2008-01-23
# 20                                    Hiromi  2008-01-24
# 21                                    Hiromi  2008-01-25
# 22                                    Hiromi  2008-01-26
# 23                                  Blackout  2008-01-26
# 24                                Yellowcard  2008-01-27
# 25                                  Blackout  2008-01-27
# 26                                    Avatar  2008-01-31
# 27                                Holy Moses  2008-01-31
# 28                                  Obituary  2008-01-31
# 29                              The Peacocks  2009-01-05
# ...                                      ...         ...
# 132282                             Threshold  2017-12-03
# 132283                         Dwight Robson  2017-12-05
# 132284               Golden Voices Of Gospel  2017-12-05
# 132285                             Gemma Ray  2017-12-05
# 132286                         Dwight Robson  2017-12-06
# 132287               Golden Voices Of Gospel  2017-12-06
# 132288                          Mnozil Brass  2017-12-06
# 132289                     Mnozil Brass 2017  2017-12-06
# 132290                         Xavier Naidoo  2017-12-06
# 132291                           Oliver Illi  2017-12-07
# 132303      La Chaux De Fonds               THEATRE POPULAIRE ROMAND
# 132304       Langnau Am Albis                        Turbine Theater
# 132305                 Luzern        cosa nostra! The Club, Casineum
# 132306                 Luzern        cosa nostra! The Club, Casineum
# 132307                 Luzern        cosa nostra! The Club, Casineum
# 132308            Lenzerheide  Andrea Bignasca @ Zauberwald Festival
# 132309                 Zurich              Tatum Rush @ Club Zukunft
# 132310                 Lugano                Tatum Rush @ Il Casotto
# 132311               Lausanne                                  MAD
#
# [132312 rows x 4 columns]

# %%
#RouteDesFestivals
#make the three time columns into a single date column

total_routedesfestivals.month.unique()
for i, month in zip(total_routedesfestivals.index, total_routedesfestivals.month) :
    if month == 'Jan.':
        total_routedesfestivals.set_value(i, 'month', 1.0)
    if month == 'Fev.':
        total_routedesfestivals.set_value(i, 'month', 2.0)
    if month == 'Mar.':
        total_routedesfestivals.set_value(i, 'month', 3.0)
    if month == 'Avr.':
        total_routedesfestivals.set_value(i, 'month', 4.0)    
    if month == 'Mai':
        total_routedesfestivals.set_value(i, 'month', 5.0)   
    if month == 'Juin':
        total_routedesfestivals.set_value(i, 'month', 6.0)      
    if month == 'Juil.':
        total_routedesfestivals.set_value(i, 'month', 7.0)
    if month == 'Aout':
        total_routedesfestivals.set_value(i, 'month', 8.0)    
    if month == 'Sep.':
        total_routedesfestivals.set_value(i, 'month', 9.0)
    if month == 'Oct.':
        total_routedesfestivals.set_value(i, 'month', 10.0)        
    if month == 'Nov.':
        total_routedesfestivals.set_value(i, 'month', 11.0)   
    if month == 'Dec.':
        total_routedesfestivals.set_value(i, 'month', 12.0)
        
total_routedesfestivals.dropna(0, inplace=True)      
total_routedesfestivals.month.apply(lambda x: pd.to_numeric(x))
total_routedesfestivals['Date'] = pd.to_datetime(total_routedesfestivals.year*10000 + total_routedesfestivals.month*100 + total_routedesfestivals.day, format="%Y%m%d")
total_routedesfestivals.drop(['day', 'month', 'year'], 1, inplace=True)
total_routedesfestivals.columns = ['Venue', 'Artist', 'City', 'Date']
total_routedesfestivals['Date'] = total_routedesfestivals['Date'].apply( lambda x: x.date() )
total_routedesfestivals
# Out:
#                                    Venue  \
# 0                   6 HOURS OF SYMPHONIA
# 1                   6 HOURS OF SYMPHONIA
# 2                   6 HOURS OF SYMPHONIA
# 3                   6 HOURS OF SYMPHONIA
# 4                                ANTIGEL
# 5                                ANTIGEL
# 6                                ANTIGEL
# 7                                ANTIGEL
# 8                                ANTIGEL
# 9                                ANTIGEL
# 10                               ANTIGEL
# 11                               ANTIGEL
# 12                               ANTIGEL
# 13                               ANTIGEL
# 14                               ANTIGEL
# 15                               ANTIGEL
# 16                               ANTIGEL
# 17       BELLUARD BOLLWERK INTERNATIONAL
# 18       BELLUARD BOLLWERK INTERNATIONAL
# 19       BELLUARD BOLLWERK INTERNATIONAL
# 20       BELLUARD BOLLWERK INTERNATIONAL
# 21       BELLUARD BOLLWERK INTERNATIONAL
# 22       BELLUARD BOLLWERK INTERNATIONAL
# 19                                      ANTOINE CHESSEX  Fribourg  2011-06-28
# 20                                      KLINGT ORGESTRA  Fribourg  2010-06-24
# 21                                     OLIVIER NUSSBAUM  Fribourg  2010-06-25
# 22                                              DJ FETT  Fribourg  2010-06-26
# 23                                          TAREK ATOUI  Fribourg  2010-06-30
# 24                                       DJ LYNDA REVOL  Fribourg  2010-06-30
# 25                                       DJ CUT ME SHOW  Fribourg  2010-07-02
# 26                                         REGGIE WATTS  Fribourg  2010-07-03
# 27                               MODIFIED TOY ORCHESTRA  Fribourg  2009-06-26
# 28                                       ANDRE DURACELL  Fribourg  2009-06-30
# 29                                          CHROME HOOF  Fribourg  2009-07-04
# ...                                                 ...       ...         ...
# 2806                                                 OY    Sierre  2011-07-03
# 2807                                        THE BAMBOOS    Sierre  2010-06-25
# 2808                                    MARIANA DA CRUZ    Sierre  2010-06-26
# 2809                                           AKATARUS    Sierre  2010-06-27
# 2810                                    GILLES PETERSON    Sierre  2009-06-26
# 2811                                         CHUCK LOVE    Sierre  2009-06-27
# 2812                                          JAZZANOVA    Sierre  2008-06-27
# 2813                                           ROB LUIS    Sierre  2008-06-27
# 2814                                             BONOBO    Sierre  2007-06-29
# 2815                                        ALEX ATTIAS    Sierre  2007-06-30
# 2816                                           DJ BLEND  Delemont  2017-02-03
# 2817                                              HAKIM  Delemont  2017-02-03
# 2818                                               SHAY  Delemont  2017-02-03
# 2819                                             TUJAMO  Delemont  2017-02-03
# 2820                                           NAOMIE K  Delemont  2017-02-03
# 2821  W AND W / W&W;  (Willem van Hanegem & Ward van...  Delemont  2017-02-03
# 2822                                         BAD NELSON  Delemont  2017-02-04
# 2823                                        IGOR BLASKA  Delemont  2017-02-04
# 2824                                      JULIAN JORDAN  Delemont  2017-02-04
# 2825                                         JERRY JOXX  Delemont  2017-02-04
# 2826                                        TONY JUNIOR  Delemont  2017-02-04
# 2827                                              KSHMR  Delemont  2017-02-04
# 2828                                       RAINER TRUBY    Leysin  2016-03-17
# 2829                                              LEFTO    Leysin  2016-03-18
# 2830                                         KIDKANEVIL    Leysin  2016-03-19
# 2831                                    GILLES PETERSON    Leysin  2016-03-20
# 2832                                      DAVID RODIGAN    Leysin  2015-03-26
# 2833                                     JULIO BASHMORE    Leysin  2015-03-27
# 2834                                BRANDT BRAUER FRICK    Leysin  2015-03-28
# 2835                                    MATTHEW HALSALL    Leysin  2015-03-29
#
# [2734 rows x 4 columns]

# %% [markdown]
# #### Unifying all

# %%
total_eventsch.set_index('Date', drop=True, append=False, inplace=True)
total_bands_in_town.set_index('Date', drop=True, append=False, inplace=True)
#total_residentadvisor.set_index('event_venue.name', drop=True, append=False, inplace=True)
total_routedesfestivals.set_index('Date', drop=True, append=False, inplace=True)

# %%
total_events = pd.concat([total_eventsch, total_bands_in_town, total_routedesfestivals])
del total_events.index.name
total_events
# Out:
#                                                        Artist            City  \
# 2017-01-20                 DJs Patric Pleasure, Ramon Ramones           Basel
# 2017-01-19          Bülent Ceylan (DE), Raffi Lusso, Miguel M          Zürich
# 2017-01-19  Nicole Johänntgen, Laurent Coulondre, Nicole J...          Zürich
# 2017-01-19                   Kool Savas (D), Vega & Bosca (D)           Basel
# 2017-01-19  Menic And The Bruncrana Firecrackers, Menic (v...            Bern
# 2017-01-19                   Charles Davis & Captured Moments      Winterthur
# 2017-01-19                                       Tin Soldiers      Frauenfeld
# 2017-01-19                                           Anna Mae      Unterägeri
# 2017-01-19        Gigi Moto, Gigi Moto (voc), JP von Dach (g)          Zürich
# 2017-01-18  Michel Wyss (voc), Ali Salvioni (perc), Mischa...            Bern
# 2017-01-18  Trio B.A.B & Hans Gysi, Alfred Zimmerlin (cell...      Winterthur
# 2017-01-18                    DJs Urbano, Jose Luis, Panthera          Luzern
# 2017-01-18                                            DJ Theo          Luzern
# 2017-01-18  Die Singphoniker, Sinfonie Orchester Biel Solo...             NaN
# 2017-01-18  Luzerner Sinfonieorchester, Jana Bouskova (Har...          Luzern
# 2017-01-18  Sinfonieorchester Basel, Kian Soltani (Vc), Le...             NaN
# 2017-01-17            Sarclo fait l'Dylan, Sarcloret (voc, g)          Zürich
# 2017-01-17                                          DJ Aystep          Zürich
# 2017-01-17              Werke von Haydn, Ignaz Pleyel, Mozart           Basel
# 2017-01-17  Orchestra Filarmonica della Fenice, Vesselina ...          Zürich
# 2017-01-17  Urte Lucht (Cemb), Werke von Anglebert, Bach, ...          Zürich
# 2017-01-17                   Mit Bachata- & Kizomba-Workshops          Zürich
# 2017-01-16  Orchestra Filarmonica Della Fenice, Vesselina ...          Luzern
# 2017-01-15  Philharmonisches Kammerorchester Berlin, Leitu...          Zürich
# 2017-01-15  Berner Jubilate Chor, Bach Collegium Bern, Mar...            Bern
# 2017-01-15  Jugend-Sinfonieorchester Aargau, Alexander Bol...           Aarau
# 2017-01-15                               DJs Momo, Alex Terry          Zürich
# 2017-01-15                   DJ Kenjiro & Grimm, ab 21 Jahren            Bern
# 2017-01-15                     DJs Undreey, Force, Nightshift          Zürich
# 2017-01-15                                   Joo Joo Eye Ball   Niederscherli
# ...                                                       ...             ...
# 2011-07-03                                                 OY          Sierre
# 2010-06-25                                        THE BAMBOOS          Sierre
# 2010-06-26                                    MARIANA DA CRUZ          Sierre
# 2010-06-27                                           AKATARUS          Sierre
# 2009-06-26                                    GILLES PETERSON          Sierre
# 2009-06-27                                         CHUCK LOVE          Sierre
# 2008-06-27                                          JAZZANOVA          Sierre
# 2008-06-27                                           ROB LUIS          Sierre
# 2007-06-29                                             BONOBO          Sierre
# 2007-06-30                                        ALEX ATTIAS          Sierre
# 2017-02-03                                           DJ BLEND        Delemont
# 2017-02-03                                              HAKIM        Delemont
# 2017-02-03                                               SHAY        Delemont
# 2017-02-03                                             TUJAMO        Delemont
# 2017-02-03                                           NAOMIE K        Delemont
# 2017-02-03  W AND W / W&W;  (Willem van Hanegem & Ward van...        Delemont
# 2017-02-04                                         BAD NELSON        Delemont
# 2017-02-04                                        IGOR BLASKA        Delemont
# 2017-02-04                                      JULIAN JORDAN        Delemont
# 2017-02-04                                         JERRY JOXX        Delemont
# 2017-02-04                                        TONY JUNIOR        Delemont
# 2017-02-04                                              KSHMR        Delemont
# 2016-03-17                                       RAINER TRUBY          Leysin
# 2016-03-18                                              LEFTO          Leysin
# 2016-03-19                                         KIDKANEVIL          Leysin
# 2016-03-20                                    GILLES PETERSON          Leysin
# 2015-03-26                                      DAVID RODIGAN          Leysin
# 2015-03-27                                     JULIO BASHMORE          Leysin
# 2015-03-28                                BRANDT BRAUER FRICK          Leysin
# 2015-03-29                                    MATTHEW HALSALL          Leysin
#
#                                               Genre  \
# 2017-01-20                           Hip Hop, R'n'B
# 2017-01-19  Ragga, Reggae, African Music, Dancehall
# 2017-01-19                        Jazz, Blues, Soul
# 2017-01-19                           Hip Hop, R'n'B
# 2017-01-19   Rock, Indie, Punk, Heavy Metal, Gothic
# 2017-01-19                        Jazz, Blues, Soul
# 2017-01-19   Rock, Indie, Punk, Heavy Metal, Gothic
# 2017-01-19   Rock, Indie, Punk, Heavy Metal, Gothic
# 2017-01-19                           Hip Hop, R'n'B
# 2017-01-18                                      Pop
# 2017-01-18                        Jazz, Blues, Soul
# 2017-01-18  Ragga, Reggae, African Music, Dancehall
# 2017-01-18  Ragga, Reggae, African Music, Dancehall
# 2017-01-18                                  Classic
# 2017-01-18                                  Classic
# 2017-01-18                                  Classic
# 2017-01-17   Rock, Indie, Punk, Heavy Metal, Gothic
# 2017-01-17                           Hip Hop, R'n'B
# 2017-01-17                                  Classic
# 2017-01-17                                  Classic
# 2017-01-17                                  Classic
# 2017-01-17  Ragga, Reggae, African Music, Dancehall
# 2017-01-16                                  Classic
# 2017-01-15                                  Classic
# 2017-01-15                                  Classic
# 2017-01-15                                  Classic
# 2017-01-15                           Hip Hop, R'n'B
# 2017-01-15                           Hip Hop, R'n'B
# 2017-01-15                           Hip Hop, R'n'B
# 2017-01-15   Rock, Indie, Punk, Heavy Metal, Gothic
# ...                                             ...
# 2011-07-03                                      NaN
# 2010-06-25                                      NaN
# 2010-06-26                                      NaN
# 2010-06-27                                      NaN
# 2009-06-26                                      NaN
# 2009-06-27                                      NaN
# 2008-06-27                                      NaN
# 2008-06-27                                      NaN
# 2007-06-29                                      NaN
# 2007-06-30                                      NaN
# 2017-02-03                                      NaN
# 2017-02-03                                      NaN
# 2017-02-03                                      NaN
# 2017-02-03                                      NaN
# 2017-02-03                                      NaN
# 2017-02-03                                      NaN
# 2017-02-04                                      NaN
# 2017-02-04                                      NaN
# 2017-02-04                                      NaN
# 2017-02-04                                      NaN
# 2017-02-04                                      NaN
# 2017-02-04                                      NaN
# 2016-03-17                                      NaN
# 2016-03-18                                      NaN
# 2016-03-19                                      NaN
# 2016-03-20                                      NaN
# 2015-03-26                                      NaN
# 2015-03-27                                      NaN
# 2015-03-28                                      NaN
# 2015-03-29                                      NaN
#
#                                          Venue
# 2017-01-20                                Balz
# 2017-01-19                           Vior Club
# 2017-01-19                               Moods
# 2017-01-19                             Kaserne
# 2017-01-19                       Mahogany Hall
# 2017-01-19                       Esse Musicbar
# 2017-01-19                           Eisenwerk
# 2017-01-19                       Seminar Hotel
# 2017-01-19                      Lebewohlfabrik
# 2017-01-18               Ono - Das Kulturlokal
# 2017-01-18                       Villa Sträuli
# 2017-01-18                              Bar 59
# 2017-01-18                           Madeleine
# 2017-01-18     Kongresshaus/Palais des Congrès
# 2017-01-18                                 KKL
# 2017-01-18               Musical Theater Basel
# 2017-01-17                           Keller 62
# 2017-01-17                       Club Flamingo
# 2017-01-17                          Oekolampad
# 2017-01-17                            Tonhalle
# 2017-01-17                     ETH Semper-Aula
# 2017-01-17                          Escherwyss
# 2017-01-16                                 KKL
# 2017-01-15                            Tonhalle
# 2017-01-15                       Kultur-Casino
# 2017-01-15               Kultur & Kongresshaus
# 2017-01-15                       Club Flamingo
# 2017-01-15                          Du Théâtre
# 2017-01-15                               Moods
# 2017-01-15                     MZH Oberscherli
# ...                                        ...
# 2011-07-03  WEEK END AU BORD DE L'EAU A SIERRE
# 2010-06-25  WEEK END AU BORD DE L'EAU A SIERRE
# 2010-06-26  WEEK END AU BORD DE L'EAU A SIERRE
# 2010-06-27  WEEK END AU BORD DE L'EAU A SIERRE
# 2009-06-26  WEEK END AU BORD DE L'EAU A SIERRE
# 2009-06-27  WEEK END AU BORD DE L'EAU A SIERRE
# 2008-06-27  WEEK END AU BORD DE L'EAU A SIERRE
# 2008-06-27  WEEK END AU BORD DE L'EAU A SIERRE
# 2007-06-29  WEEK END AU BORD DE L'EAU A SIERRE
# 2007-06-30  WEEK END AU BORD DE L'EAU A SIERRE
# 2017-02-03               WINTER SOUND FESTIVAL
# 2017-02-03               WINTER SOUND FESTIVAL
# 2017-02-03               WINTER SOUND FESTIVAL
# 2017-02-03               WINTER SOUND FESTIVAL
# 2017-02-03               WINTER SOUND FESTIVAL
# 2017-02-03               WINTER SOUND FESTIVAL
# 2017-02-04               WINTER SOUND FESTIVAL
# 2017-02-04               WINTER SOUND FESTIVAL
# 2017-02-04               WINTER SOUND FESTIVAL
# 2017-02-04               WINTER SOUND FESTIVAL
# 2017-02-04               WINTER SOUND FESTIVAL
# 2017-02-04               WINTER SOUND FESTIVAL
# 2016-03-17           WORLDWIDE FESTIVAL LEYSIN
# 2016-03-18           WORLDWIDE FESTIVAL LEYSIN
# 2016-03-19           WORLDWIDE FESTIVAL LEYSIN
# 2016-03-20           WORLDWIDE FESTIVAL LEYSIN
# 2015-03-26           WORLDWIDE FESTIVAL LEYSIN
# 2015-03-27           WORLDWIDE FESTIVAL LEYSIN
# 2015-03-28           WORLDWIDE FESTIVAL LEYSIN
# 2015-03-29           WORLDWIDE FESTIVAL LEYSIN
#
# [152293 rows x 4 columns]

# %%
#Write the DataFrame to a csv file
filename = 'total_events.csv'
pd.DataFrame(total_events, columns=list(total_events.columns)).to_csv(filename, index=False, encoding="utf-8")
print('Total events data saved to file')
# Out:
# Total events data saved to file
