# %% [markdown]
# # Preprocessing pipeline
# In this notebook, we will clean and agglomerate the data acquired from several platforms to be used conveniently for analysis.

# %%
import pandas as pd
import os
import glob
import urllib
import requests
import time
import json
from pandas.io.json import json_normalize
from IPython.display import clear_output
import numpy as np
import bandsInTownHelper as bandsInTownHelper

import pycountry
import country_demonyms

# %%
#Load the total_x events data into several DataFrame.

total_eventsch = pd.read_csv(os.path.join('./total_eventsch.csv'))
total_bands_in_town = pd.read_csv(os.path.join('./total_bands_in_town.csv'))
total_residentadvisor = pd.read_csv(os.path.join('./total_residentadvisor.csv'))
total_routedesfestivals = pd.read_csv(os.path.join('./total_routedesfestivals.csv'))

# %% [markdown]
# ## Unifying the representation
# The data gathered on several platforms came in a handful of shapes that we should now normalize while retaining as much information. We will discards platforms only'ids.

# %% [markdown]
# #### Events.ch
# à compléter

# %%
total_eventsch = pd.read_csv(os.path.join('./total_eventsch.csv'))
total_eventsch['Date'] = pd.to_datetime(total_eventsch['Date'])
total_eventsch['Date'] = total_eventsch['Date'].apply( lambda x: x.date() )

total_eventsch_classic = total_eventsch.loc[total_eventsch.Genre == 'Classic']
total_eventsch = total_eventsch.select(lambda x: x not in total_eventsch_classic.index)
#musicgraph_several = musicgraph_missing[musicgraph_missing.name.str.contains(',')]

df_columns=['Artist', 'Date', 'Genre', 'Venue', 'City']
total_eventsch_processed=pd.DataFrame(columns=df_columns)

for index, artist in zip(total_eventsch.index, total_eventsch.Artist) :
    for name in artist.split(',') :
        name=name.strip()
        if  (len(name) != 0 and name[0].isupper()) :
            new_row = pd.DataFrame([[name, total_eventsch.loc[index].Date, total_eventsch.loc[index].Genre, total_eventsch.loc[index].Venue, total_eventsch.loc[index].City]], columns = df_columns)
            total_eventsch_processed = total_eventsch_processed.append(new_row)
            
total_eventsch_processed.reset_index(drop = True, inplace=True)

# %%
#Find origin based on artist name
country_name = []
country_alpha2 = []
country_alpha3 = []
for country in list(pycountry.countries) :
    if ' ' not in country.name :
        country_name.append(country.name)
    country_alpha2.append(country.alpha_2)
    country_alpha3.append(country.alpha_3)
country_alpha2.remove('DJ')
country_alpha2.remove('MC') 
#not sure this is true
#country_dict['(de)'] = 'Germany'
country_dict['schweizer'] = 'Switzerland'



for index, genre in zip(total_eventsch_processed.index, total_eventsch_processed.Artist) :
    for word in genre.split() :
        if word in country_name :
            total_eventsch_processed.set_value(index, 'origin', word)
        elif (word[1:-1] in country_alpha2 and '(' in word and ')' in word) :
            total_eventsch_processed.set_value(index, 'origin', pycountry.countries.lookup(word[1:-1]).name)
        elif (word[1:-1] in country_alpha3 and '(' in word and ')' in word) :
            total_eventsch_processed.set_value(index, 'origin', pycountry.countries.lookup(word[1:-1]).name)
        elif word.lower() in country_dict :
            total_eventsch_processed.set_value(index, 'origin', country_dict[word.lower()])

total_eventsch_processed.Artist.replace(' \(.*\) .*','', regex=True, inplace=True)
total_eventsch_processed.Artist.replace(' \(.*\)','', regex=True, inplace=True)
total_eventsch_processed.Artist.replace(' \(.*','', regex=True, inplace=True)

# %%
total_eventsch_artists = total_eventsch_processed.copy()
total_eventsch_artists.drop('Date', axis=1, inplace = True)
total_eventsch_artists.drop('Venue', axis=1, inplace = True)
total_eventsch_artists.drop('City', axis=1, inplace = True)
total_eventsch_artists.columns = ['name', 'genre', 'origin']
total_eventsch_artists["ambigous_result"] = np.nan
total_eventsch_artists["no_result"] = np.nan
total_eventsch_artists.drop_duplicates('name', inplace= True)
total_eventsch_artists.name.size
# Out:
# 19179

# %%
i = 0
for name in total_musicgraph.name.unique() :
       if name in total_eventsch_artists.name.unique():
            if ((pd.isnull(total_musicgraph.loc[total_musicgraph['name'] == name].genre.any()) == False) and (pd.isnull(total_musicgraph.loc[total_musicgraph['name'] == name].origin.any()) == False)) :
                total_eventsch_artists.drop(total_eventsch_artists.loc[total_eventsch_artists['name'] == name].index, inplace=True)


#musicgraph_missing = total_musicgraph.loc[total_musicgraph['no_result'] == 1]

# %%
#Write the DataFrame to a csv file
filename = 'total_eventsch_artists.csv'
pd.DataFrame(total_eventsch_artists, columns=list(total_eventsch_artists.columns)).to_csv(filename, index=True, encoding="utf-8")
print('Total events data saved to file')
# Out:
# Total events data saved to file

# %%
total_eventsch_artists.name.size
# Out:
# 12957

# %% [markdown]
# #### BandsInTown
# à compléter

# %%
total_bands_in_town.drop(['artist_url', 'event_id', 'event_url', 'event_venue.region', 'event_venue.url', 'event_venue.id'], 1, inplace=True)

#Convert time column to datetime objects
total_bands_in_town['event_datetime'] = pd.to_datetime(total_bands_in_town['event_datetime'])
#Remove time from dates
total_bands_in_town['event_datetime'] = total_bands_in_town['event_datetime'].apply( lambda x: x.date() )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-229-2ce891adb687> in <module>()
# ----> 1 total_bands_in_town.drop(['artist_url', 'event_id', 'event_url', 'event_venue.region', 'event_venue.url', 'event_venue.id'], 1, inplace=True)
#       2
#       3 #Convert time column to datetime objects
#       4 total_bands_in_town['event_datetime'] = pd.to_datetime(total_bands_in_town['event_datetime'])
#       5 #Remove time from dates
#
# C:\Users\Mathieu\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1906             else:
# -> 1907                 new_axis = axis.drop(labels, errors=errors)
#    1908             dropped = self.reindex(**{axis_name: new_axis})
#    1909             try:
#
# C:\Users\Mathieu\Anaconda3\lib\site-packages\pandas\indexes\base.py in drop(self, labels, errors)
#    3260             if errors != 'ignore':
#    3261                 raise ValueError('labels %s not contained in axis' %
# -> 3262                                  labels[mask])
#    3263             indexer = indexer[~mask]
#    3264         return self.delete(indexer)
#
# ValueError: labels ['artist_url' 'event_id' 'event_url' 'event_venue.region' 'event_venue.url'
#  'event_venue.id'] not contained in axis

# %%
total_bands_in_town.head(10)
# Out:
#     artist_name event_datetime       event_venue.city  event_venue.latitude  \
# 0   Groombridge     2006-01-06             Langenthal             47.212060
# 1      Painhead     2006-01-07              Rorschach             47.477928
# 2        shEver     2006-01-14                    Zug             47.182220
# 3      Painhead     2006-01-15  Gossau (Sankt Gallen)             47.414415
# 4    Mando Diao     2006-01-21                   Laax             46.800000
# 5  Foo Fighters     2006-01-25             Winterthur             47.495655
# 6   Groombridge     2006-01-27               Burgdorf             47.050000
# 7   Groombridge     2007-01-01                  Berne             46.948432
# 8      Painhead     2007-01-06                Sommeri             47.566667
# 9        shEver     2007-01-13                 Zurich             47.386620
#
#    event_venue.longitude              event_venue.name
# 0               7.789998                Rock in Church
# 1               9.495190                   Hafenbuffet
# 2               8.520760                  Industrie 45
# 3               9.254950                    The Office
# 4               9.250000  PALACE CLUB AT RIDERS PALACE
# 5               8.748480              Eishalle Duetwag
# 6               7.616667                      Gymfest
# 7               7.440461                           ONO
# 8               9.283333                    Löwenarena
# 9               8.534380                        Werk21

# %% [markdown]
# ##### Venues location
# Bands in Town data associates coordinates to each venue, which could be interesting for representing our findings on maps. We will extract those in a separate DataFrame, and then drop the coordinates from the events DataFrame. For simplicity, we will leave in the venue and city columns. We will come back to the venues DataFrame later on.

# %%
#Better to drop the coordinates from the event frame for clarity
venues = total_bands_in_town[['event_venue.name', 'event_venue.city', 'event_venue.latitude', 'event_venue.longitude']].copy()
total_bands_in_town.drop(['event_venue.latitude', 'event_venue.longitude'], 1, inplace=True)

venues.drop_duplicates(subset=['event_venue.longitude', 'event_venue.latitude'], inplace=True)
venues.drop_duplicates('event_venue.name', inplace=True)
venues.set_index('event_venue.name', drop=True, append=False, inplace=True)
del venues.index.name
venues = venues.sort_index()

venues_ra = total_residentadvisor[['club_name', 'club_adress']].copy()
venues_ra.drop_duplicates('club_name', inplace=True)
venues_ra.set_index('club_name', drop=True, append=False, inplace=True)
del venues_ra.index.name

total_bands_in_town.columns = ['Artist', 'Date', 'City', 'Venue']

# %% [markdown]
# #### ResidentAdvisor
# à compléter

# %%
#Extract cities from addresses of clubs in ResidentAdvisor data
for i, address in zip(total_residentadvisor.index, total_residentadvisor.club_adress) :
    total_residentadvisor.set_value(i, 'City', address.rsplit(None, 1)[-1])
    

#Manually fill wrong entries
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '2' ].index.tolist(), 'City', 'Zurich')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '1009' ].index.tolist(), 'City', 'Pully')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '4001' ].index.tolist(), 'City', 'Basel')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '1227' ].index.tolist(), 'City', 'Geneva')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == 'BL' ].index.tolist(), 'City', 'Münchenstein')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '40/42' ].index.tolist(), 'City', 'Wetzikon')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '22' ].index.tolist(), 'City', 'Bern')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '/' ].index.tolist(), 'City', 'Murten')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '253' ].index.tolist(), 'City', 'Les Diablerets')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '14' ].index.tolist(), 'City', 'Basel')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '10' ].index.tolist(), 'City', 'Basel')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '-' ].index.tolist(), 'City', 'Biel/Bienne')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '(GR)' ].index.tolist(), 'City', 'Klosters')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == 'ZH' ].index.tolist(), 'City', 'Zurich')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '4058' ].index.tolist(), 'City', 'Basel')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '1' ].index.tolist(), 'City', 'Baden')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '6020' ].index.tolist(), 'City', 'Emmenbrücke')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '8143' ].index.tolist(), 'City', 'Zurich')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == '2,6612,Ascona,(Ti),CH' ].index.tolist(), 'City', 'Ascona')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['City'] == 'ZG' ].index.tolist(), 'City', 'Baar ')

total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Rue des Grands-Vergers, 1957 Ardon, CH' ].index.tolist(), 'City', 'Ardon')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Av. de Tivoli 3, Fribourg, 1700, CH' ].index.tolist(), 'City', 'Fribourg')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Köniz, 3098, 9 Schulhausgässli, CH' ].index.tolist(), 'City', 'Köniz')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Unterer Graben 17, 9000 St. Gallen, CH' ].index.tolist(), 'City', 'St. Gallen')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Viale Castagnola 6, 6900 Lugano, CH' ].index.tolist(), 'City', 'Lugano')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Via Alla Foce 1, 6982 Agno, Ticino, CH' ].index.tolist(), 'City', 'Agno')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Via Pioda 12, 6900 Lugano, CH' ].index.tolist(), 'City', 'Lugano')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Ancienne-Pointe 16, 1920 Martigny, CH' ].index.tolist(), 'City', 'Martigny')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Freilager-Platz 9, 4142 Münchenstein/Basel, CH' ].index.tolist(), 'City', 'Basel')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Via Industria 4; 6814, Lamone Ticino' ].index.tolist(), 'City', 'Lamone')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Ponte Capriasca, Ticino' ].index.tolist(), 'City', 'Ponte Capriasca')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Case postale 352 Crans, Valais' ].index.tolist(), 'City', 'Crans-Montana')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Place centrale, 1997 Nendaz, Valais' ].index.tolist(), 'City', 'Nendaz')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Place de la Gare, 1957 Ardon, Valais, Suisse' ].index.tolist(), 'City', 'Ardon')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Rue du Commerce 122, 2300 La Chaux-de-Fonds, Suisse' ].index.tolist(), 'City', 'La Chaux-de-Fonds')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Place Centrale, 1870 Monthey, Valais, Suisse' ].index.tolist(), 'City', 'Monthey')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Chemin des Batailles, 1214 VERNIER (GENEVE), Suisse' ].index.tolist(), 'City', 'Vernier')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Rue de Vevey 34, 1630 Bulle, SWITZERLAND' ].index.tolist(), 'City', 'Bulle')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Sant Gallen, SWITZERLAND' ].index.tolist(), 'City', 'St. Gallen')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'Steinberggasse 16' ].index.tolist(), 'City', 'Winterthur')
total_residentadvisor.set_value(total_residentadvisor.loc[total_residentadvisor['club_adress'] == 'St. Annagasse 16' ].index.tolist(), 'City', 'Zurich')

total_residentadvisor.drop(total_residentadvisor.loc[total_residentadvisor['City'] == 'Liechtenstein' ].index.tolist(), inplace=True)

total_residentadvisor.drop(['club_adress'], 1, inplace=True)

#Convert events date to datetime objects
for i, date in zip(total_residentadvisor.index, total_residentadvisor.date) :
    total_residentadvisor.set_value(i, 'date', pd.to_datetime(date[5:]))
#Remove hour from dates
total_residentadvisor['date'] = total_residentadvisor['date'].apply( lambda x: x.date() )        

total_residentadvisor.columns = ['Venue', 'Date', 'Artist', 'City']

# %%
total_residentadvisor.head(10)
# Out:
#                       Venue        Date         Artist    City
# 0   2. Akt Restaurant & Bar  2015-09-19         Affani  Zurich
# 1   2. Akt Restaurant & Bar  2015-09-19  Mark Faermont  Zurich
# 2   2. Akt Restaurant & Bar  2015-09-12   Mucho Stylez  Zurich
# 3   2. Akt Restaurant & Bar  2015-07-03   Mucho Stylez  Zurich
# 4   2. Akt Restaurant & Bar  2015-06-13   Mucho Stylez  Zurich
# 5   2. Akt Restaurant & Bar  2015-03-21  Mark Faermont  Zurich
# 6   2. Akt Restaurant & Bar  2015-01-17   Carlos Russo  Zurich
# 7   2. Akt Restaurant & Bar  2015-01-17  Mark Faermont  Zurich
# 8   2. Akt Restaurant & Bar  2014-11-29          Tonka  Zurich
# 9   2. Akt Restaurant & Bar  2014-11-29  Mark Faermont  Zurich

# %% [markdown]
# #### RouteDesFestivals
# à compléter

# %%
#make the three time columns into a single date column

total_routedesfestivals.month.unique()
for i, month in zip(total_routedesfestivals.index, total_routedesfestivals.month) :
    if month == 'Jan.':
        total_routedesfestivals.set_value(i, 'month', 1.0)
    if month == 'Fev.':
        total_routedesfestivals.set_value(i, 'month', 2.0)
    if month == 'Mar.':
        total_routedesfestivals.set_value(i, 'month', 3.0)
    if month == 'Avr.':
        total_routedesfestivals.set_value(i, 'month', 4.0)    
    if month == 'Mai':
        total_routedesfestivals.set_value(i, 'month', 5.0)   
    if month == 'Juin':
        total_routedesfestivals.set_value(i, 'month', 6.0)      
    if month == 'Juil.':
        total_routedesfestivals.set_value(i, 'month', 7.0)
    if month == 'Aout':
        total_routedesfestivals.set_value(i, 'month', 8.0)    
    if month == 'Sep.':
        total_routedesfestivals.set_value(i, 'month', 9.0)
    if month == 'Oct.':
        total_routedesfestivals.set_value(i, 'month', 10.0)        
    if month == 'Nov.':
        total_routedesfestivals.set_value(i, 'month', 11.0)   
    if month == 'Dec.':
        total_routedesfestivals.set_value(i, 'month', 12.0)
        
total_routedesfestivals.dropna(0, inplace=True)    

total_routedesfestivals.month.apply(lambda x: pd.to_numeric(x))
total_routedesfestivals['Date'] = pd.to_datetime(total_routedesfestivals.year*10000 + total_routedesfestivals.month*100 + total_routedesfestivals.day, format="%Y%m%d")
total_routedesfestivals.drop(['day', 'month', 'year'], 1, inplace=True)

#We add this line to avoid type error on the datetimeindex when concatenating all frames
total_routedesfestivals['Date'] = pd.to_datetime(total_routedesfestivals['Date'])
#Remove hour from dates
total_routedesfestivals['Date'] = total_routedesfestivals['Date'].apply( lambda x: x.date() )

total_routedesfestivals.columns = ['Venue', 'Artist', 'City', 'Date']

# %%
total_routedesfestivals.head(10)
# Out:
#                   Venue               Artist      City        Date
# 0  6 HOURS OF SYMPHONIA          SYNMETALIUM  Lausanne  2017-04-01
# 1  6 HOURS OF SYMPHONIA             EVENMORE  Lausanne  2017-04-01
# 2  6 HOURS OF SYMPHONIA               SECHEM  Lausanne  2017-04-01
# 3  6 HOURS OF SYMPHONIA   BEYOND FORGIVENESS  Lausanne  2017-04-01
# 4               ANTIGEL                 ZERO    Geneve  2017-01-27
# 5               ANTIGEL  MAY B (MAGUY MARIN)    Geneve  2017-01-28
# 6               ANTIGEL  MAY B (MAGUY MARIN)    Geneve  2017-01-29
# 7               ANTIGEL         TRENTEMOLLER    Geneve  2017-02-02
# 8               ANTIGEL          THE NOTWIST    Geneve  2017-02-03
# 9               ANTIGEL            HENRI DES    Geneve  2017-02-05

# %% [markdown]
# #### Putting it all together

# %%
total_events
total_events = pd.concat([total_eventsch, total_bands_in_town, total_routedesfestivals, total_residentadvisor])

# 17229  Ensemble erzsébet, Isabel Heusser (S), Roberth...  2013-01-06
# 17230  Das kleine Zürcher Ensemble, Céline Akça (Mezz...  2013-01-06
# 17231  Ad hoc-Chor der Predigerkirche, Leitung: David...  2013-01-06
# 17232   Violaklasse von Salome Janner, Musikschule Basel  2013-01-06
# 17233                          DJs Sir George, Rick Tick  2013-01-06
# 17234           DJs Big Boys, Southern Flash, Hotfingerz  2013-01-06
# 17235                                           DJ Black  2013-01-05
# 17236                    Terrible Feelings (SWE), Norton  2013-01-05
# 17237                                     Baby Halbstark  2013-01-05
# 17238                                         Led Airbus  2013-01-05
# 17239        Robert Alexander & The Last Cowboys, DJ Uas  2013-01-05
# 17240                                   Norman Die, Noan  2013-01-05
# 17241                            Stress, support: M.A.M.  2013-01-05
# 17242  DJs Yuma, Peter Wermelinger, GMF, The Clients,...  2013-01-05
# 17243                                           Keltikon  2013-01-05
# 17244                                 DJs Caroline, Benu  2013-01-05
# 17245  Peregrina, Kelly Landerkin, Lorenza Donadini, ...  2013-01-05
# 17246  Klezmer plus, Fides Auf der Maur (Klar), Patri...  2013-01-05
#
#                                          Genre  \
# 0                               Hip Hop, R'n'B
# 1      Ragga, Reggae, African Music, Dancehall
# 2                            Jazz, Blues, Soul
# 3                               Hip Hop, R'n'B
# 4       Rock, Indie, Punk, Heavy Metal, Gothic
# 5                            Jazz, Blues, Soul
# 6       Rock, Indie, Punk, Heavy Metal, Gothic
# 7       Rock, Indie, Punk, Heavy Metal, Gothic
# 8                               Hip Hop, R'n'B
# 9                                          Pop
# 10                           Jazz, Blues, Soul
# 11     Ragga, Reggae, African Music, Dancehall
# 12     Ragga, Reggae, African Music, Dancehall
# 13                                     Classic
# 14                                     Classic
# 15                                     Classic
# 16      Rock, Indie, Punk, Heavy Metal, Gothic
# 17                              Hip Hop, R'n'B
# 18                                     Classic
# 19                                     Classic
# 20                                     Classic
# 21     Ragga, Reggae, African Music, Dancehall
# 22                                     Classic
# 23                                     Classic
# 24                                     Classic
# 25                                     Classic
# 26                              Hip Hop, R'n'B
# 27                              Hip Hop, R'n'B
# 28                              Hip Hop, R'n'B
# 29      Rock, Indie, Punk, Heavy Metal, Gothic
# ...                                        ...
# 17217                                      Pop
# 17218   Rock, Indie, Punk, Heavy Metal, Gothic
# 17219                                      Pop
# 17220                           Hip Hop, R'n'B
# 17221                                  Classic
# 17222                                      Pop
# 17223                                      Pop
# 17224  Ragga, Reggae, African Music, Dancehall
# 17225                        Jazz, Blues, Soul
# 17226   Rock, Indie, Punk, Heavy Metal, Gothic
# 17227                        Jazz, Blues, Soul
# 17228                                  Classic
# 17229                                  Classic
# 17230                                  Classic
# 17231                                  Classic
# 17232                                  Classic
# 17233                           Hip Hop, R'n'B
# 17234                           Hip Hop, R'n'B
# 17235                           Hip Hop, R'n'B
# 17236                                      Pop
# 17237                                      Pop
# 17238   Rock, Indie, Punk, Heavy Metal, Gothic
# 17239   Rock, Indie, Punk, Heavy Metal, Gothic
# 17240   Rock, Indie, Punk, Heavy Metal, Gothic
# 17241                                      Pop
# 17242                           Hip Hop, R'n'B
# 17243   Rock, Indie, Punk, Heavy Metal, Gothic
# 17244   Rock, Indie, Punk, Heavy Metal, Gothic
# 17245                                  Classic
# 17246                                  Classic
#
#                                          Venue            City
# 0                                         Balz           Basel
# 1                                    Vior Club          Zürich
# 2                                        Moods          Zürich
# 3                                      Kaserne           Basel
# 4                                Mahogany Hall            Bern
# 5                                Esse Musicbar      Winterthur
# 6                                    Eisenwerk      Frauenfeld
# 7                                Seminar Hotel      Unterägeri
# 8                               Lebewohlfabrik          Zürich
# 9                        Ono - Das Kulturlokal            Bern
# 10                               Villa Sträuli      Winterthur
# 11                                      Bar 59          Luzern
# 12                                   Madeleine          Luzern
# 13             Kongresshaus/Palais des Congrès             NaN
# 14                                         KKL          Luzern
# 15                       Musical Theater Basel             NaN
# 16                                   Keller 62          Zürich
# 17                               Club Flamingo          Zürich
# 18                                  Oekolampad           Basel
# 19                                    Tonhalle          Zürich
# 20                             ETH Semper-Aula          Zürich
# 21                                  Escherwyss          Zürich
# 22                                         KKL          Luzern
# 23                                    Tonhalle          Zürich
# 24                               Kultur-Casino            Bern
# 25                       Kultur & Kongresshaus           Aarau
# 26                               Club Flamingo          Zürich
# 27                                  Du Théâtre            Bern
# 28                                       Moods          Zürich
# 29                             MZH Oberscherli   Niederscherli
# ...                                        ...             ...
# 17217                              Hafenkneipe          Zürich
# 17218                                   Dynamo          Zürich
# 17219                           Bierhalle Wolf          Zürich
# 17220                        Albani Music Club      Winterthur
# 17221                     Musik-Akademie Basel           Basel
# 17222                                  Portier      Winterthur
# 17223                           Bierhalle Wolf          Zürich
# 17224                               Kaufleuten          Zürich
# 17225                       Turnhalle im Progr            Bern
# 17226                                 El Lokal          Zürich
# 17227  WIM - Werkstatt für improvisierte Musik          Zürich
# 17228          Kongresshaus/Palais des Congrès             NaN
# 17229                            Ackermannshof           Basel
# 17230                          Ev.-ref. Kirche            Elgg
# 17231                           Predigerkirche          Zürich
# 17232                     Musik-Akademie Basel           Basel
# 17233                                 Q Zurich          Zürich
# 17234                                   Velvet           Basel
# 17235                        Hey City of Music          Zürich
# 17236                   Restaurant Hirscheneck           Basel
# 17237                                 Helsinki          Zürich
# 17238                                 Bad Bonn        Düdingen
# 17239                             Gewerbehalle          Luzern
# 17240                                 Gleis 13       Reussbühl
# 17241                               Nordportal           Baden
# 17242                             Chollerhalle             Zug
# 17243                             Marquee Club          Zürich
# 17244                                 Baranoff            Thun
# 17245                      Kirche Heilig Kreuz       Binningen
# 17246              Ref. Kirchgemeindehaus Enge          Zürich
#
# [17247 rows x 5 columns]

# %%
#Write the DataFrame to a csv file
filename = 'total_events.csv'
pd.DataFrame(total_events, columns=list(total_events.columns)).to_csv(filename, index=True, encoding="utf-8")
print('Total events data saved to file')
# Out:
# Total events data saved to file

# %% [markdown]
# ## Genres and origins
#
# Divide the data we have after calling the MusicGraph API into two subsets : one which has value filled in nicely (~35%) which  we'll call clean, another one with 'assumed' correct artist names but missing genre and origin information, and a third where information is missing, and rows may contain more than one artist in their name. The last subset may require extra handling care with regard to the events frame.
# BIG PART of exploratory data analysis

# %%
#Get Spotify genre data
total_spotify    = pd.read_csv(os.path.join('./total_artists_Spotify.csv'))
total_spotify    = total_spotify.loc[pd.isnull(total_spotify['genre']) == False]
#Get MusicGraph genre and origin data
total_musicgraph = pd.read_csv(os.path.join('./total_artists_MusicGraph.csv'))


musicgraph_missing = total_musicgraph.loc[total_musicgraph['no_result'] == 1]
musicgraph_several = musicgraph_missing[musicgraph_missing.name.str.contains(',')]
musicgraph_missing = musicgraph_missing.select(lambda x: x not in musicgraph_several.index)

# %% [markdown]
# First, we will try to fill in the missing genre value with the data acquired from Spotify. To do so, we first have to clean Spotify data, which gives us very specific genres (720 !) instead of global names such as MusicGenre. Some origin information may also be included in the specific genres, which we should look for carefully.

# %%
# Out:
#        ambigous_result genre  \
# 602                  0   NaN
# 4911                 0   NaN
# 7627                 0   NaN
# 10247                0   NaN
# 12122                0   NaN
# 12306                0   NaN
# 12638                0   NaN
# 13030                0   NaN
# 13032                0   NaN
# 14245                0   NaN
# 14477                0   NaN
# 14919                0   NaN
# 14994                0   NaN
# 15136                0   NaN
# 15762                0   NaN
# 16364                0   NaN
# 16740                0   NaN
# 16828                0   NaN
# 17662                0   NaN
# 18341                0   NaN
# 18343                0   NaN
# 18344                0   NaN
# 19072                0   NaN
# 19075                0   NaN
# 19076                0   NaN
# 19077                0   NaN
# 19078                0   NaN
# 19080                0   NaN
# 19081                0   NaN
# 19082                0   NaN
# ...                ...   ...
# 60835                0   NaN
# 60836                0   NaN
# 60837                0   NaN
# 60838                0   NaN
# 60839                0   NaN
# 60863                0   NaN
# 60864                0   NaN
# 60865                0   NaN
# 60867                0   NaN
# 60868                0   NaN
# 60873                0   NaN
# 60874                0   NaN
# 60878                0   NaN
# 60881                0   NaN
# 60882                0   NaN
# 60883                0   NaN
# 60887                0   NaN
# 60888                0   NaN
# 60889                0   NaN
# 60892                0   NaN
# 60896                0   NaN
# 60901                0   NaN
# 60915                0   NaN
# 60921                0   NaN
# 60924                0   NaN
# 60925                0   NaN
# 60926                0   NaN
# 60927                0   NaN
# 61364                0   NaN
# 61989                0   NaN
#
#                                                     name  no_result origin
# 602                      THE GOOD, THE BAD AND THE QUEEN          1    NaN
# 4911                                   Police, Adjective          1    NaN
# 7627                MASSIVEDRUM - DJ, PRODUCER & REMIXER          1    NaN
# 10247                   Until You See, Until You Believe          1    NaN
# 12122                                       DieDrums, DJ          1    NaN
# 12306                            Naturally 7, Tom Freund          1    NaN
# 12638  Carnifex, Beneath The Massacre, Molotov Soluti...          1    NaN
# 13030  Heaven Shall Burn, Unearth, Rise to Remain, Na...          1    NaN
# 13032                             FU** ART, LET'S DANCE!          1    NaN
# 14245              Ruffpack, Dancehall Soldiers, DJ Peak          1    NaN
# 14477                                    Fanga, Afrobeat          1    NaN
# 14919           Limp Bizkit, The Offspring and many more          1    NaN
# 14994  MACHINE HEAD, LAMB OF GOD, KILLSWITCH ENGAGE, ...          1    NaN
# 15136  Pat Metheny, Chris Potter, Antonio Sanchez & B...          1    NaN
# 15762                      BoySetsFire, Madball and more          1    NaN
# 16364                                Zebda, Bénabar, ...          1    NaN
# 16740                           Peace , Love and Gaga <3          1    NaN
# 16828  iwrestledabearonce, Oceano, For All Those Slee...          1    NaN
# 17662                                    I, The Deceiver          1    NaN
# 18341                 CeCe Rogers Lead singer, Keyboards          1    NaN
# 18343                                Danny Vocals, Drums          1    NaN
# 18344                             Filippo Vocals, Guitar          1    NaN
# 19072                    Terrible Feelings (SWE), Norton          1    NaN
# 19075        Robert Alexander & The Last Cowboys, DJ Uas          1    NaN
# 19076                                   Norman Die, Noan          1    NaN
# 19077                            Stress, support: M.A.M.          1    NaN
# 19078  DJs Yuma, Peter Wermelinger, GMF, The Clients,...          1    NaN
# 19080                                 DJs Caroline, Benu          1    NaN
# 19081  Peregrina, Kelly Landerkin, Lorenza Donadini, ...          1    NaN
# 19082  Klezmer plus, Fides Auf der Maur (Klar), Patri...          1    NaN
# ...                                                  ...        ...    ...
# 60835  Silverblue (Plattentaufe), Invivas, DJ Franky ...          1    NaN
# 60836  Ronny Graupe's Spoom, Ronny Graupe (g), Jonas ...          1    NaN
# 60837  Film Hot Sugars Cold World (USA, 2015), live: ...          1    NaN
# 60838                    Dick Laurent, Pyrolyzed, Mantra          1    NaN
# 60839  Simon Baumann & Fabian Kalker, Simon Baumann (...          1    NaN
# 60863  DJs K-Rim, Pfund 500, Sweap, Big Boys, ab 20 J...          1    NaN
# 60864  Live: XV Kilist & Rocco, DJs Frisk & Index, Ar...          1    NaN
# 60865                  DJs Certified, Croma, Curtis Bleu          1    NaN
# 60867                     DJs Undreey, Force, Nightshift          1    NaN
# 60868                               DJs Momo, Alex Terry          1    NaN
# 60873  Philharmonisches Kammerorchester Berlin, Leitu...          1    NaN
# 60874  Berner Jubilate Chor, Bach Collegium Bern, Mar...          1    NaN
# 60878  Orchestra Filarmonica Della Fenice, Vesselina ...          1    NaN
# 60881  Urte Lucht (Cemb), Werke von Anglebert, Bach, ...          1    NaN
# 60882  Orchestra Filarmonica della Fenice, Vesselina ...          1    NaN
# 60883              Werke von Haydn, Ignaz Pleyel, Mozart          1    NaN
# 60887            Sarclo fait l'Dylan, Sarcloret (voc, g)          1    NaN
# 60888  Trio B.A.B & Hans Gysi, Alfred Zimmerlin (cell...          1    NaN
# 60889  Michel Wyss (voc), Ali Salvioni (perc), Mischa...          1    NaN
# 60892  Die Singphoniker, Sinfonie Orchester Biel Solo...          1    NaN
# 60896  Luzerner Sinfonieorchester, Jana Bouskova (Har...          1    NaN
# 60901  Sinfonieorchester Basel, Kian Soltani (Vc), Le...          1    NaN
# 60915  Menic And The Bruncrana Firecrackers, Menic (v...          1    NaN
# 60921        Gigi Moto, Gigi Moto (voc), JP von Dach (g)          1    NaN
# 60924                   Kool Savas (D), Vega & Bosca (D)          1    NaN
# 60925  Nicole Johänntgen, Laurent Coulondre, Nicole J...          1    NaN
# 60926          Bülent Ceylan (DE), Raffi Lusso, Miguel M          1    NaN
# 60927                 DJs Patric Pleasure, Ramon Ramones          1    NaN
# 61364                         Julie Marghilano, Dana Ruh          1    NaN
# 61989                          Jeanine De Bique, Soprano          1    NaN
#
# [10102 rows x 5 columns]

# %%
#Create a dict of Country adjective to Country name
country_dict = {}
for key, value in country_demonyms.COUNTRY_DEMONYMS.items():
    country_dict[value.lower()] = key.lower().title()
    
country_dict['persian'] = 'Iran'
country_dict['breton'] = 'France'
country_dict['argentine'] = 'Argentina'
country_dict['fado'] = 'Portugal'
country_dict['quebecois'] = 'Canada'
country_dict['americana'] = 'United States'
country_dict['j-ambient'] = 'Japan'
country_dict['k-pop'] = 'Korea'
country_dict['uk'] = 'United Kingdom'
country_dict['k-indie'] = 'Korea'
country_dict['j-reggae'] = 'Japan'
country_dict['j-metal'] = 'Japan'
country_dict['j-core'] = 'Japan'
country_dict['j-punk'] = 'Japan'
country_dict['sertanejo'] = 'Brasil'
country_dict['japanoise'] = 'Japan'
country_dict['magyar'] = 'Hungary'
country_dict['j-rock'] = 'Japan'
country_dict['francais'] = 'France'
country_dict['chalga'] = 'Bulgaria'
country_dict['napoletana'] = 'Italy'
country_dict['bhangra'] = 'India'
country_dict['carnatic'] = 'India'
country_dict['forro'] = 'Brasil'
country_dict['entehno'] = 'Greece'
country_dict['bay'] = 'United States'
country_dict['schlager'] = 'Germany'
country_dict['coast'] = 'United States'
country_dict['j-dance'] = 'Japan'
country_dict['k-hop'] = 'Korea'
country_dict['francoton'] = 'France'
country_dict['corsican'] = 'France'
country_dict['british'] = 'United Kingdom'
country_dict['c-pop'] = 'China'

# %%
total_spotify = total_spotify.select(lambda x: (x in musicgraph_several.index) or (x in musicgraph_missing.index))
print('Total number of genres from Spotify :', total_spotify.genre.unique().size)
print('Total helpful lines from Spotify :', total_spotify.name.size)


i=0
for index, genre in zip(total_spotify.index, total_spotify.genre) :
    for word in genre.split() :
        if word in country_dict :
            if index in musicgraph_missing.index :
                musicgraph_missing.set_value(index, 'origin', country_dict[word])
            elif index in musicgraph_several.index :
                musicgraph_several.set_value(index, 'origin', country_dict[word])
            i+=1
print('With Spotify, we get the origin of', i, 'more artists.')
# Out:
# Total number of genres from Spotify : 466
# Total helpful lines from Spotify : 1067
# With Spotify, we get the origin of 183 more artists.

# %%
genre_dict = {}

# We will have to simplify as we don't have so much time for thorough classification of genres
Electronica = ['house','aggrotech','danspunk', 'brostep', 'abstract', 'chillwave','drone', 'chill', 'beats', 'experimental','electropunk',  'turbo', 'balearic','dance-punk', 'ebm','edm', 'j-dance', 'chillstep','darkpsy', 'darkstep', 'chalga', 'japanoise', 'lounge', 'psytrance', 'tekno','indietronica', 'electronica',  'techno','disco', 'j-ambient',   'noise', 'bass', 'electroclash', 'wave', 'trance', 'ambient', 'dancehall', 'beat', 'dance', 'dub', 'electro', 'eurodance', 'dubstep', 'electronic', 'psych', 'industrial', 'microhouse', 'electrofox', ]
for key in Electronica:
    genre_dict[key] = 'Electronica/Dance'
Rock = ['rock','rock-and-roll','neo-progressive','tribute','post-screamo', 'hardstyle', 'speedcore', 'neo-psychedelic', 'ostrock','neo-rockabilly', 'britpop', 'j-punk','grunge','breakcore', 'goregrind','orgcore','j-rock', 'alternative', 'j-core', 'j-metal', 'k-indie', 'screamocore', 'grindcore', 'nerdcore',  'doomcore', 'sludge',   'core','deathcore',  'gamecore', 'metalcore','post-punk', 'garage','thrash','post-metal', 'psychobilly', 'edge', 'mathcore',  'punk', 'emo', 'indie', 'metal', 'hardcore',  'djent', 'doom', 'glam', 'oi', 'nwobhm']
for key in Rock:
    genre_dict[key] = 'Rock'
Pop = ['pop','popgaze', 'idol','etherpop','anti-folk',  'chanson','c-pop', 'k-pop', 'europop', 'neo-synthpop', 'synthpop', 'folk-pop', 'freak', 'eurovision', 'futurepop']
for key in Pop:
    genre_dict[key] = 'Pop'
Reggae = ['reggae', 'ska', 'reggaeton', 'euroska','j-reggae' ]
for key in Reggae:
    genre_dict[key] = 'Reggae/Ska'
Jazz = ['jazz', 'bebop', 'ragtime', 'afrobeat']
for key in Jazz:
    genre_dict[key] = 'Jazz'
World = ['rai','accordeon', 'entehno',  'african','schlager','corsican','breton', 'asian', 'british',  'arab','armenian', 'kurdish',  'balkan', 'world', 'napoletana','bhangra', 'polka', 'folkmusik', 'andean', 'panpipe', 'maghreb','magyar',  'fado','traditional', 'quebecois', 'carnatic', 'native', 'klezmer', 'world', 'celtic', 'bangla', 'pagode', 'flamenco', 'throat', 'medieval', 'capoeira']
for key in World:
    genre_dict[key] = 'World'
RB = ['r&b', 'funk', 'funky', 'soul']
for key in RB:
    genre_dict[key] = 'Soul/R&B'
Country = ['bluegrass', 'country', 'barbershop', 'americana', 'bluegrass', 'cajun']
for key in Country:
    genre_dict[key] = 'Country'
Latin = ['forro' ,'nu-cumbia', 'sertanejo', 'salsa','tango','merengue', 'bachata', 'rumba', 'nova', 'latin', 'cumbia']
for key in Latin:
    genre_dict[key] = 'Latin'
Rap = ['hop', 'rap', 'trap', 'k-hop', 'francoton']
for key in Rap:
    genre_dict[key] = 'Rap/Hip Hop'
Blues = ['blues', 'blues-rock', 'swing', 'boogie-woogie']
for key in Blues:
    genre_dict[key] = 'Blues'
Classical = ['cello','cappella',  'concert', 'opera', 'choral', 'clarinet', 'classical', 'violin', 'harpsichord', 'string', 'brass', 'orchestral', 'baroque', 'harp', 'early']
for key in Classical:
    genre_dict[key] = 'Classical/Opera'
Soundtracks = ['movie', 'tunes', 'hollywood', 'soundtrack' ]
for key in Soundtracks:
    genre_dict[key] = 'Soundtracks'
Gospel = ['gospel', 'christian', 'liturgical', 'christmas', 'ccm', 'worship']
for key in Gospel:
    genre_dict[key] = 'Christian/Gospel'
NewAge = ['age', 'kirtan', 'didgeridoo']
for key in NewAge:
    genre_dict[key] = 'New Age'

i=0
for index, genre in zip(total_spotify.index, total_spotify.genre) :
    for word in genre.split() :
        if word in genre_dict :
            total_spotify.set_value(index, 'genre', genre_dict[word])
            if index in musicgraph_missing.index :
                musicgraph_missing.set_value(index, 'genre', genre_dict[word])
            elif index in musicgraph_several.index :
                musicgraph_several.set_value(index, 'genre', genre_dict[word])
            i+=1

# %%
genres = total_musicgraph.genre.unique()
i = 0
for genre in total_spotify.genre :
    if genre not in genres :
        i+=1
print(i/total_spotify.size*100 , '% of events which subgenre were not parsed')
# Out:
# 2.19306466729 % of events which subgenre were not parsed

# %%
for index in musicgraph_missing.index :
    if not pd.isnull(musicgraph_missing.loc[index].genre) :
        total_musicgraph.set_value(index, 'genre', musicgraph_missing.loc[index].genre)
        if not pd.isnull(musicgraph_missing.loc[index].origin) :
            total_musicgraph.set_value(index, 'origin', musicgraph_missing.loc[index].origin)
            musicgraph_missing.drop(index, inplace=True)
            
for index in musicgraph_several.index :
    if not pd.isnull(musicgraph_several.loc[index].genre) :
        total_musicgraph.set_value(index, 'genre', musicgraph_several.loc[index].genre)
        if not pd.isnull(musicgraph_several.loc[index].origin) :
            total_musicgraph.set_value(index, 'origin', musicgraph_several.loc[index].origin)
            musicgraph_several.drop(index, inplace=True)

# %%
#Intermediary save
filename = 'total_artists_processed.csv'
pd.DataFrame(total_musicgraph, columns=list(total_musicgraph.columns)).to_csv(filename, index=False, encoding="utf-8")
print('Total processed artists data saved to file')
# Out:
# Total processed artists data saved to file

# %% [markdown]
# ### Artists with unresolved names

# %%
musicgraph_missing
musicgraph_several
# Out:
#        ambigous_result genre  \
# 602                  0  Rock
# 4911                 0   NaN
# 7627                 0   NaN
# 10247                0   NaN
# 12122                0   NaN
# 12306                0   NaN
# 12638                0   NaN
# 13030                0   NaN
# 13032                0   NaN
# 14245                0   NaN
# 14477                0   NaN
# 14919                0   NaN
# 14994                0   NaN
# 15136                0   NaN
# 15762                0   NaN
# 16364                0   NaN
# 16740                0   NaN
# 16828                0   NaN
# 17662                0   NaN
# 18341                0   NaN
# 18343                0   NaN
# 18344                0   NaN
# 19072                0   NaN
# 19075                0   NaN
# 19076                0   NaN
# 19077                0   NaN
# 19078                0   NaN
# 19080                0   NaN
# 19081                0   NaN
# 19082                0   NaN
# ...                ...   ...
# 60835                0   NaN
# 60836                0   NaN
# 60837                0   NaN
# 60838                0   NaN
# 60839                0   NaN
# 60863                0   NaN
# 60864                0   NaN
# 60865                0   NaN
# 60867                0   NaN
# 60868                0   NaN
# 60873                0   NaN
# 60874                0   NaN
# 60878                0   NaN
# 60881                0   NaN
# 60882                0   NaN
# 60883                0   NaN
# 60887                0   NaN
# 60888                0   NaN
# 60889                0   NaN
# 60892                0   NaN
# 60896                0   NaN
# 60901                0   NaN
# 60915                0   NaN
# 60921                0   NaN
# 60924                0   NaN
# 60925                0   NaN
# 60926                0   NaN
# 60927                0   NaN
# 61364                0   NaN
# 61989                0   NaN
#
#                                                     name  no_result origin
# 602                      THE GOOD, THE BAD AND THE QUEEN          1    NaN
# 4911                                   Police, Adjective          1    NaN
# 7627                MASSIVEDRUM - DJ, PRODUCER & REMIXER          1    NaN
# 10247                   Until You See, Until You Believe          1    NaN
# 12122                                       DieDrums, DJ          1    NaN
# 12306                            Naturally 7, Tom Freund          1    NaN
# 12638  Carnifex, Beneath The Massacre, Molotov Soluti...          1    NaN
# 13030  Heaven Shall Burn, Unearth, Rise to Remain, Na...          1    NaN
# 13032                             FU** ART, LET'S DANCE!          1    NaN
# 14245              Ruffpack, Dancehall Soldiers, DJ Peak          1    NaN
# 14477                                    Fanga, Afrobeat          1    NaN
# 14919           Limp Bizkit, The Offspring and many more          1    NaN
# 14994  MACHINE HEAD, LAMB OF GOD, KILLSWITCH ENGAGE, ...          1    NaN
# 15136  Pat Metheny, Chris Potter, Antonio Sanchez & B...          1    NaN
# 15762                      BoySetsFire, Madball and more          1    NaN
# 16364                                Zebda, Bénabar, ...          1    NaN
# 16740                           Peace , Love and Gaga <3          1    NaN
# 16828  iwrestledabearonce, Oceano, For All Those Slee...          1    NaN
# 17662                                    I, The Deceiver          1    NaN
# 18341                 CeCe Rogers Lead singer, Keyboards          1    NaN
# 18343                                Danny Vocals, Drums          1    NaN
# 18344                             Filippo Vocals, Guitar          1    NaN
# 19072                    Terrible Feelings (SWE), Norton          1    NaN
# 19075        Robert Alexander & The Last Cowboys, DJ Uas          1    NaN
# 19076                                   Norman Die, Noan          1    NaN
# 19077                            Stress, support: M.A.M.          1    NaN
# 19078  DJs Yuma, Peter Wermelinger, GMF, The Clients,...          1    NaN
# 19080                                 DJs Caroline, Benu          1    NaN
# 19081  Peregrina, Kelly Landerkin, Lorenza Donadini, ...          1    NaN
# 19082  Klezmer plus, Fides Auf der Maur (Klar), Patri...          1    NaN
# ...                                                  ...        ...    ...
# 60835  Silverblue (Plattentaufe), Invivas, DJ Franky ...          1    NaN
# 60836  Ronny Graupe's Spoom, Ronny Graupe (g), Jonas ...          1    NaN
# 60837  Film Hot Sugars Cold World (USA, 2015), live: ...          1    NaN
# 60838                    Dick Laurent, Pyrolyzed, Mantra          1    NaN
# 60839  Simon Baumann & Fabian Kalker, Simon Baumann (...          1    NaN
# 60863  DJs K-Rim, Pfund 500, Sweap, Big Boys, ab 20 J...          1    NaN
# 60864  Live: XV Kilist & Rocco, DJs Frisk & Index, Ar...          1    NaN
# 60865                  DJs Certified, Croma, Curtis Bleu          1    NaN
# 60867                     DJs Undreey, Force, Nightshift          1    NaN
# 60868                               DJs Momo, Alex Terry          1    NaN
# 60873  Philharmonisches Kammerorchester Berlin, Leitu...          1    NaN
# 60874  Berner Jubilate Chor, Bach Collegium Bern, Mar...          1    NaN
# 60878  Orchestra Filarmonica Della Fenice, Vesselina ...          1    NaN
# 60881  Urte Lucht (Cemb), Werke von Anglebert, Bach, ...          1    NaN
# 60882  Orchestra Filarmonica della Fenice, Vesselina ...          1    NaN
# 60883              Werke von Haydn, Ignaz Pleyel, Mozart          1    NaN
# 60887            Sarclo fait l'Dylan, Sarcloret (voc, g)          1    NaN
# 60888  Trio B.A.B & Hans Gysi, Alfred Zimmerlin (cell...          1    NaN
# 60889  Michel Wyss (voc), Ali Salvioni (perc), Mischa...          1    NaN
# 60892  Die Singphoniker, Sinfonie Orchester Biel Solo...          1    NaN
# 60896  Luzerner Sinfonieorchester, Jana Bouskova (Har...          1    NaN
# 60901  Sinfonieorchester Basel, Kian Soltani (Vc), Le...          1    NaN
# 60915  Menic And The Bruncrana Firecrackers, Menic (v...          1    NaN
# 60921        Gigi Moto, Gigi Moto (voc), JP von Dach (g)          1    NaN
# 60924                   Kool Savas (D), Vega & Bosca (D)          1    NaN
# 60925  Nicole Johänntgen, Laurent Coulondre, Nicole J...          1    NaN
# 60926          Bülent Ceylan (DE), Raffi Lusso, Miguel M          1    NaN
# 60927                 DJs Patric Pleasure, Ramon Ramones          1    NaN
# 61364                         Julie Marghilano, Dana Ruh          1    NaN
# 61989                          Jeanine De Bique, Soprano          1    NaN
#
# [10094 rows x 5 columns]

# %%
#Find origin based on artist name
musicgraph_several2 = musicgraph_several.copy()
country_name = []
country_alpha2 = []
country_alpha3 = []
for country in list(pycountry.countries) :
    if ' ' not in country.name :
        country_name.append(country.name)
    country_alpha2.append(country.alpha_2)
    country_alpha3.append(country.alpha_3)
country_alpha2.remove('DJ')
country_alpha2.remove('MC') 
#not sure this is true
#country_dict['(de)'] = 'Germany'
country_dict['schweizer'] = 'Switzerland'



for index, genre in zip(musicgraph_several2.index, musicgraph_several2.name) :
    for word in genre.split() :
        if word.endswith(',') :
            word = word[:-1]
        if word in country_name :
            musicgraph_several2.set_value(index, 'origin', word)
        elif (word[1:-1] in country_alpha2 and '(' in word and ')' in word) :
            musicgraph_several2.set_value(index, 'origin', pycountry.countries.lookup(word[1:-1]).name)
        elif (word[1:-1] in country_alpha3 and '(' in word and ')' in word) :
            musicgraph_several2.set_value(index, 'origin', pycountry.countries.lookup(word[1:-1]).name)
        elif word.lower() in country_dict :
            musicgraph_several2.set_value(index, 'origin', country_dict[word.lower()])

# %%
 musicgraph_several2.name.size
# Out:
# 3575

# %%
Electronica = ['DJ','DJs', 'MC']
Jazz = ['jazz', '(sax)','impro',  'quintet', '(tp)', 'saxophon', 'cohen', '(sax,', 'trio', 'quartet']
Classical = ['(kl)','vokal', 'musikschule','philharmon', 'symphony','chamber', 'werke', 'camerata','hochschule','schola', 'musikkollegium', 'kammerorchester', 'beethoven', 'ravel', 'schubert', 'chor' , 'sinfonie', 'mozart', 'orchester', 'bach', 'vivaldi', 'mendelsohn', 'strauss', 'hilharmonie']  
Rock = ['rusted', 'nihilists', 'tribute', 'rock', 'metal', 'punk' ]
Latin = ['piazzolla', 'latin']
Blues = ['blues', 'swing', 'boogie']
Rap = ['crew']
for index, name in zip(musicgraph_several2.index, musicgraph_several2.name) :  
        if any(word in name for word in Electronica):
            total_musicgraph.set_value(index, 'genre','Electronica/Dance')
            if not pd.isnull(musicgraph_several2.loc[index].origin) :
                total_musicgraph.set_value(index, 'origin', musicgraph_several2.loc[index].origin)
            musicgraph_several2.drop(index, inplace=True)
        elif any(word in name.lower() for word in Latin): 
            total_musicgraph.set_value(index, 'genre','Latin')
            if not pd.isnull(musicgraph_several2.loc[index].origin) :
                total_musicgraph.set_value(index, 'origin', musicgraph_several2.loc[index].origin)
            musicgraph_several2.drop(index, inplace=True)
        elif any(word in name.lower() for word in Blues): 
            total_musicgraph.set_value(index, 'genre','Blues')
            if not pd.isnull(musicgraph_several2.loc[index].origin) :
                total_musicgraph.set_value(index, 'origin', musicgraph_several2.loc[index].origin)
            musicgraph_several2.drop(index, inplace=True)
        elif (any(word in name.lower() for word in Jazz) and not any(word in name.lower() for word in Classical)) : 
            total_musicgraph.set_value(index, 'genre','Jazz')
            if not pd.isnull(musicgraph_several2.loc[index].origin) :
                total_musicgraph.set_value(index, 'origin', musicgraph_several2.loc[index].origin)
            musicgraph_several2.drop(index, inplace=True)
        elif any(word in name.lower() for word in Rock): 
            total_musicgraph.set_value(index, 'genre','Rock')
            if not pd.isnull(musicgraph_several2.loc[index].origin) :
                total_musicgraph.set_value(index, 'origin', musicgraph_several2.loc[index].origin)
            musicgraph_several2.drop(index, inplace=True)
        elif any(word in name.lower() for word in Classical): 
            total_musicgraph.set_value(index, 'genre','Classical/Opera')
            if not pd.isnull(musicgraph_several2.loc[index].origin) :
                total_musicgraph.set_value(index, 'origin', musicgraph_several2.loc[index].origin)
            musicgraph_several2.drop(index, inplace=True)
        elif any(word in name.lower() for word in Rap): 
            total_musicgraph.set_value(index, 'genre','Rap')
            if not pd.isnull(musicgraph_several2.loc[index].origin) :
                total_musicgraph.set_value(index, 'origin', musicgraph_several2.loc[index].origin)
            musicgraph_several2.drop(index, inplace=True)

# %%
from collections import Counter
i =0
for name in musicgraph_several2.name :
    #if len(name) > 70 :
    if 'impro' in name.lower() :
        print(name)
        i+=1
        print('')
print(i)

#Counter(" ".join(musicgraph_several2["name"]).split()).most_common(200)
# Out:
# Mega Horvath (p), Improvisationen von Slow bis Tempo
#
# Freie Gesangs-Improvisation mit Gabriela Tanner, Susanne Petersen, Verena Barbara Gohl, Christina Jaccard und dem Publikum
#
# Lundi gras, mit Studierenden der Klasse freie Improvisation von Fred Frith und Alfred Zimmerlin
#
# Impro Duo, Justin Purtill (voc, g), Samuel Dühsler (dr)
#
# Dirk Elsemann (Org), Improvisationen über Schweizer Volkslieder
#
# Malcolm Braff (p), Laboratorium - Konzertreihe für frei improvisierte Musik
#
# 6

# %%
 pycountry.countries.get(alpha_2='US')
# Out:
# Country(alpha_2='US', alpha_3='USA', name='United States', numeric='840', official_name='United States of America')

# %%
i =0
for name in musicgraph_several.name :
    #if len(name) > 70 :
        print(name)
        i+=1
print(i)
# Out:
# THE GOOD, THE BAD AND THE QUEEN
# Police, Adjective
# MASSIVEDRUM - DJ, PRODUCER & REMIXER
# Until You See, Until You Believe
# DieDrums, DJ
# Naturally 7, Tom Freund
# Carnifex, Beneath The Massacre, Molotov Solution, Betraying The Martyrs
# Heaven Shall Burn, Unearth, Rise to Remain, Naeara
# FU** ART, LET'S DANCE!
# Ruffpack, Dancehall Soldiers, DJ Peak
# DJs Skoob, Link
# Firemoon, DJ Joey Roxx
# Hans Christoph Begemann (B, Bar), Leitung: Otto Tausk, Werke von Wagner, Diepenbrock, Debussy
# Duo Buck-Wolfarth, Christian Buck (g), Christian Wolfarth (dr), Werke von Katharina Weber, Jack Callahan, Alex Goretzki u. a.
# Das Internationale Johann Strauss Orchester, Leitung: Georg Kugi
# Colin Vallon Trio, Colin Vallon (p), Patrice Moret (b), Julian Sartorius (dr)
# Disgroove, Jack Dancing
# DJs Innox, Soundschnuppe, Pinkpanther
# Lisa de la Salle (Kl), Werke von Schumann, Chopin
# Petra Vogel (voc), Alain Veltin (p), Emanuel Schnyder (b), Lisette Spinnler (voc), Michi Stulz (d), Gina Günthard (voc)
# DJs Momo, Vega S
# DJs Thrasher, Mosh
# DJs Kraut & Ruben, Luxus, Etienne
# DJs Steve Supreme, Cutxact, 2 Eazy
# Loco Slickers (album release), Frequency Jones (g, electr), Dan Agent (key), Micro Jackson (dr), visuals by The Lighting Lash, hosted by MC Miss Mad
# Orchestre de la Suisse Romande, Emmanuel Pahud (Fl), Leitung: Charles Dutoit, Werke von Berlioz, Mozart, Martin, Mussorgski
# DJs Herr Wempe, Directoscut
# The National Fanfare of Kadebostany, visuals by Supermafia
# DJs M-Live, Q-Drop, Cochano, ab 21 Jahren
# DJs Alex, Vega S
# Big Freedia (USA), DJ Wildlife
# DJs Deefly, Shorty Real, Soul Sista, Flamin Fingaz
# Zürcher Bach Chor, cantus firmus consort, Sarah Wegener (S), Barbara Erni (A), Michael Feyfar (T), Dominik Wörner (Bar), Leitung: Andreas Reize, Werke von Mendelssohn
# Lusciniol, Meret Roth (S), Aline Burla (Fl), Cristina Janet (Vc), Jonas Zürcher (Cemb), Werke von Scarlatti, Händel, Frescobaldi, Gabrielli
# Chor und Orchester Uni Basel, PR, Werke von Schubert, Berio, Ravel
# Kammerorchester der Basler Chemie KOBC, Leitung: Désirée Pousaz, Werke von H. Purcell, W. Boyce, J. Ch. Bach, G. F. Händel, J. Ch. Pepusch
# Gitarrenklasse Walter Feybli, Hochschule für Musik Basel
# Red Shamrock, Keltikon
# Nik Bärtsch's Ronin, Bernhard Wagner
# Noëmi Nadelmann (S), André Desponds (Kl)
# Zone Expérimentale, Master-Studiengang zeitgenössische Musik
# DJs Santino, Volcano, Volino
# Juilliard String Quartet (USA), Werke von Mozart, Beethoven
# Aurel Hassler (voc), Christian Winiker (g), Mani Zweili (b), Mike Malloth (dr)
# Session, hosted by Vic Hofstetter
# DJs Emigrante, Ruben
# Steamboat Switzerland X/XII, Get out of My Room, Dominik Blum (hammond), Marino Pliakas (b), Lucas Niggli (dr)
# Karma to Burn, Rozbub, Das Röckt
# Sinfonie Orchester Biel, Louis Schwizgebel (Kl), Leitung: Gábor Takás-Nagy, Werke von Roussel, Mozart, Schubert
# Leitung: Marcus Weiss (Saxofon-Klasse), Christian Dierstein (Schlagzeug-Klasse), Solo-Abend der Klassen für Schlagzeug und Saxofon der Hochschule für Musik Basel
# DJ Janosch, ab 18 Jahren, dance animation by Taxi Dancers
# Andrea Gygax (voc), Alexandra Huber (voc), Angela Beffa (g), Simone Lustenberger (p), Danja Schwegler (b), Julia Keller (dr)
# Zürcher Kammerorchester, Nik Bärtsch (Kl), Sha (Klar), Mats Eser (Perk)
# Tonhalle-Orchester Zürich, András Schiff (Kl), Leitung: Bernard Haitink, Werke von Brahms, Beethoven
# Labrador City, Zigitros
# Iscapes 3, James Bailey (voc), Christian Rösli (synth), Marius Peyer (g), Fabian Gutscher (voc), Thomas Winkler (electr), visuals by pulp.noir
# John Marshall & Ferdinand Povel Quintet, John Marshall (tp), Ferdinand Povel (ts), Andrea Pozza (p), Stephan Kurmann (b), Peter Schmidlin (dr), auch um 21.45 Uhr
# Greis, Greis (voc), Benjamin Noti (g), Claude Bucher (dj, electronics), JJ Flück (dr)
# Julian Sartorius, Trixa Arnold, Acousmatic Jug Band
# Dejan Terzic, Hayden Chisholm (as), Achim Kaufmann (p), Ronny Graupe (g), Dejan Terzic (dr)
# Fabian M. Mueller (p), Marco Müller (b), Dominic Egli (dr), Offene Jamsession
# Subtil, The Dues, Tobias Kölla
# Fischermanns Orchestra, Breakfast on a Battlefield, Gaël Zwahlen (g), Lionel Gafner (b), Adrien Guerne (ts), Lionel Friedli (dr)
# Navel, Scumbucket (D)
# Arc-en-Ciel, in Zusammenarbeit mit dem Ensemble Vertigo Chamber der HKB
# Bo-Katzman-Chor, Leitung: Bo Katzman
# Philharmonisches Bläserquintett Berlin, Ewa Kupiec (Kl), Werke von Farkas, Beethoven, Ligeti u. a.
# Chor und Orchester der Oberstufe RSS Basel, Werke von Sweelinck, Vivaldi, Mendelsohn
# Chor Divertimento vocale Freiburg, Werke von Haydn
# Angelika Express (D), DJs Dannyramone, Evil Home Stereo
# DJs Slice, Warren
# DJs Sir Jai, Task, presented by NoHook
# DJs I M, Chronic, Hotfingerz, Evans, Philly, live: Fat Joe
# DJs Ker, Luciano
# Einat & Hakim (ISR), DJ Audio Tribe
# DJs Kaiser Dias, Richy, Autentico
# ZHAW-Chor alpha-cappella, Leitung: Paolo Vignoli, Werke von Juan Arnez
# Böblinger Vokalensemble, Elisabeth Berner (Org, Kl), Leitung: Tilman Jäger
# Marco von Orelli 5, Marco von Orelli (tp), Lukas Briggen (tb), Michel Wintsch (p), Kaspar von Grünigen (b), Samuel Dühsler (dr)
# DJs Flyer, Res
# DJs Magnum (F), Big Tex (USA), ab 21 Jahren
# Grave Digger, Wizard, Majesty, Gun Barrel
# Lilly Thornten Quintett (CD-Release), Lilly Thornton (voc), Christian Meyers (tp), Ull Möck (p), Jens Loh (b), Eckhard Stromer (dr), hosted by Tages-Anzeiger Act
# Christoph Stiefel Isorhythm Orchestra, Sarah Büchi (voc), Matthieu Michel (tp, flh), Domenic Landolf (ts, bcl), Adrian Mears (tb), Christoph Stiefel (p), Arne Huber (b), Kevin Chesham (dr)
# Klenze Duo, David Frühwirth (V), Johannes Zahlten (Va), Werke von Ignaz Josef Pleyel, Bela Bartok, Gordon Jakob u. a.
# DJs Hispanic Joe, Rocksteady, Reggie Saunders (voc), ab 22 Jahren, dance animation by Milkshakers
# DJs ATN, Subculture, Soul Sista
# DJs Aystep, Tenzking, K-Risma, ab 21 Jahren
# Euphonia Ensemble, Yama Luberti Kapidani, Markelian Kapidani, Sandro Schneebeli, Violeta Zaplitnii, Radu Zaplitnii, Yuri Goloubev, Asaf Sirkis
# Werner Bärtschi (Kl), Werke von Beethoven, Brahms, Chopin, Liszt
# Wenzel & Band, Hans-Eckhardt Wenzel (voc, g), Hannes Scheffler (g, b), Thommy Krawallo (g), Stefan Dohanetz (dr, perc)
# Phoenix Basel, Leitung: Jürg Henneberger
# Dead Ghosts (CAN), support: TJ Spool
# Olivier Ker Ourio Quartet, Olivier Ker Ourio (acc), Emmanuel Bex (hammond), Jérôme Barde (g), Matthieu Chazarenc (dr)
# Gabriel Beurle, Jazzkollektiv Basel
# XL-Target feat. Mr. Defunkt Joe Bowie, Joseph Bowie (tb, voc), Christy Doran (g), KJ Dave Doran (dr), Dany Trutt (dr)
# Philharmonisches Orchester Jena, Leitung: Marc Tardue, Werke von Grieg, Nicolai, Verdi, Ponchielli u. a., auch um 19.30 Uhr
# Marianne Racine Quartet, Marianne Racine (voc, p), Daniel Baschnagel (tp), Patrick Sommer (b), Pius Baschnagel (dr), Reihe: Jazzapero
# Eveleen Olsen (V), Annette Kappeler (V), Verena Zauner (Vc), Emanuel Schmelzer (Cemb), Werke von Matteis
# Alestorm (SCO), Arkona (RUS), Thyrfing (SWE), Ex Deo (CAN), Wolfchant (D), Borholm (HUN), ab 16 Jahren, Paganfest
# Werner Gisin (tb), Jerry Guanter (tp), Henry Bodmer (ss), Hans Bächtold (bjo), Simon Inäbnit (p), Ivo Maynard (tuba), Hans Kilchenmann (dr)
# Daniel Schläppi Duo, Marc Copland (p), Daniel Schläppi (b), Essentials
# Proton Bern, Leitung: Matthias Kuhn
# Unifour Country Band, Swiss Highwaymen
# DJs M-Live, A. S. One
# Schnaak, Lune Palmer
# Box feat. Black Cracker, Sky 189 & Claire Huguenin
# Journeys, Angelo Signore (p, key), Willy Kotoun (perc), Philippe Mall (sax), Robert Mark (dr, perc), Luciano Maranta (b), Dennis Roshard (g)
# Flava Sauce, Valentin Bächi (key), Manu Rindlisbacher (b), Tobias Hunziker (dr)
# Daniel Schläppi with Marc Copland (CD Release), Daniel Schläppi (b), Marc Copland (p)
# Duo Leresche, Fabienne Leresche (V), Patrick Leresche (Kl), Werke von Bach, Ysaye, Rachmaninov
# Berner Symphonieorchester, Damenchor Konzert Theater Bern, Anu Komsi (S), Leitung: Heinz Holliger, Werke von Mendelssohn Bartholdy, Heinz Holliger, Debussy
# 11 AM (Plattentaufe), Street Corner Talking
# Joan Faulkner (USA), Csik Gustav (USA)
# Morning Transfer (CD-Release), Calumet, DJ Goofy
# Micha Sportelli Micha Sportelli und Band (B), Lorin Far
# DJs Source, Leventation, Laslow, Max Iron, M-Flava, Pe-Be
# Diens, support: C.Mee, Phumaso, Smack
# DJs Gordon, Limone, Musi
# The Jeff Hamilton Trio, Jeff Hamilton (dr), Tamir Hendelman (p), Christoph Luty (b)
# Gideon (USA), support: Fathoms (GB), Here Lies A Warning (GB)
# Klasse für Studienvorbereitung, Leitung: David Lauri
# K.O.S. Crew, Ruff Pack Int.
# Anstatt Guitar Hero zu spielen, selber musizieren
# Der Wawawa, Benedikt Reising (sax), Marco Müller (b), Rico Baumann (dr), Reihe: Jazz am Mittwoch
# Christophe Berruex (Kl), Werke von Liszt, Wagner, Gluck
# Enno Bungers (D), Acapulco Stage Divers
# Patrick Archer Accoustics, DJ Konserve
# Of Monsters And Men (ISL), support: Mugison (ISL)
# I am Hersey (USA), support: Hierophant (I)
# Los Angeles Philharmonic, Leitung: Gustavo Dudamel, Werke von Claude Vivier, Debussy, Strawinski
# Rolf Raggenbass & Country Heart Band, Michelle Ryser, Tom Astor & Band (D)
# The Lucky & Tamara Peterson Band (USA), Lucky Peterson (g, voc), Tamara Peterson (voc), Shawn Kellerman (g), Tim Waites (b), Raul Valdes (dr)
# Sinfonie-Ensemble, Leitung: Mathias Inoue, Gevorg Gharabekyan, Olivier Mueller, Werke von Mozart, Mendelssohn
# Julia Marion (Fag), Schola Cantorum Basiliensis - Hochschule für Alte Musik
# Ilios Quartett, Andrzej Kilian (V), Seiko Morishita (V), Dominik Ostertag (Va), Anita Federli-Rutz (Vc), Bernhard Parz (Kl), Werke von Aljabjew, Mieczyslaw Weinberg, Lunchkonzert
# Festival Strings Lucerne, Teilnehmer des Meisterkurses, Leitung: Bernard Haitink, Werke von Mozart, Beethoven, Brahms, Bruckner, Debussy
# Cojazz Invites Alice Day, Alice Day (voc), Andy Scherrer (p), Stephan Kurmann (b), Peter Schmidlin (dr), auch um 21.45 Uhr
# Irène Schweizer & Pierre Favre, Irène Schweizer (p), Pierre Favre (dr)
# Shakra, ab 16 Jahren
# Adriana Marfisi (S), Leitung: Nello Santi, Werke von Verdi
# Basement Saints, Mother Razorblade, Six Finger Jäck, DJ Höllehond
# International Trio Plus One, David Boeddinghaus (p), Trevor Richards (dr), Olivier Franc (ss), Reimer von Essen (cl)
# Doctors Order, DJ Tschuppi
# Stuck in Traffic, Anict, Sway 89, Tobi Gmür & The Homesick Five, Weekend Phantom
# Smack, Phumaso & C.Mee, Webba, Pyro, Mimiks, Zuger Shuger & Fix Finest
# DJs Hispanic Joe, Panamasta, ab 20 Jahren
# Murphy Left, Falco Meyer (voc, g, p), Wolf Meyer (voc, b, p), Meta Amstad (cl, voc), Salome Bossard (cl, voc), Samuel Büttiker (dr), DJ Bob Rock
# Scratch Bandits (F), DJs Redrum, Mike Steez, B2K
# DJs Q-Fu , Ms Brownsugar
# Theos Fried Chickenstore, Church of Confidence
# Das Pferd, Moonshaped, DJs Case, Secret, L4P, 50 Jahre Jubiläum
# Eugenio Finardi, The Flag
# DJs Simon Moser, Fame Luck
# DJs Q-Drop, Levi Blind
# DJs K-Rim, Mykel Rozenberg
# DJs D-Rock, I-Scratch
# Lisette Spinnler & Christoph Stiefel, hosted by Jazz im Seefeld
# Kantorei St. Peter Zürich, Nadja Baccetta (Org), Anja Kühn (A), David Munderloh (T), Ismael Arróniz (B), Leitung: Kantor Sebastian Goll, Werke von Händel
# Aargauer Symphonie Orchester, Werke von Mozart, Haydn, Roussel, Ravel
# Luzerner Sinfonieorchester LSO, Leitung: James Gaffigan, Werke von Bach, Konzerteinführung durch Thomas Meyer um 18.30
# Glarisegger Chor, Ensemble la fontaine, Werke von Bach
# Franz Liszt Kammerorchester, Emmanuel Pahud (Fl), Werke von Bach, Vivaldi, Purcell, Mozart u. a., Einführung um 19.15 Uhr
# Bern Community Choir, Voice Affair, Moossee Gospel Singers
# Trio Arens, Jenny, Lorenzi, Götz Arens (p), Marc Jenny (b), Carlo Lorenzi (dr)
# Kapnorth, Babyflipper-Summit, Lauter Haus DJs, hosted by Lauter Leute
# Deutsche Filmorchester Babelsberg, Paul Kuhn, Willy Ketzer, Martin Gjakanovski, Rüdiger Baldauf, Dusko Goykovich, Gustl Meyer u. a., Paul Kuhn - 85 Jahre jung
# Blé Noir & Whitching Tales, Doppelkonzert
# Reformierter Kirchenchor Höngg, Kammerorchester Aceras, Robert Schmid (Org), Franziska Wigger-Lötscher (S), Leitung: Peter Aregger, Werke von Homilius
# Voodoo People, DJs Diferenz, F, visuals by Pulp
# Nige Bray, DJ Konserve
# Die Atzen, DJs Mouse, Greenhorn
# DJs Riz, Scratch, Ker, Wiz, Gee One
# The Gee Strings (D), The Irradiates (F), Batalj (D), The Escalator Haters
# Misty Blue, Arlette Keiser-Singy (g, voc), Sarah Fischer Ryter (g, voc), Hansj Looser (bjo, Mandoline, voc), Peter Keiser (b)
# Roy & the Devils Motorcycle, Fai Baba, DJ Augenwasser
# DJs Pat Farrell, Mad Morris, Rakim, All Star Resident DJs, live: Patrick Nuo
# DJs Hispanic Joe, Die-Scorp
# The Realness, DJs L-Cut, Kristo, Blaster B
# Claire Huguenin (voc), Luzius Schuler (key), Christian Spahni (b), Domi Chansorn (dm), hosted by Claire Huguenin
# DJs Alma Negras Genesis, Luxus, live: Calibro 35 (I), zwei Jahre Sud, ein Jahr Elch Records
# Galatea Quartett, Vocalensemble Consonans, Leitung: Karl Scheuber, Werke von Francis Poulenc, Haydn
# Martin Schaefer (V), Christian Mettler (Kl)
# Anna Buczek Merz (Org), Rahel Keiser (Sprecherin), Werke von Dupré, mit Texten von Paul Claudel
# Muriel Schwarz (S), Aurea Marston (A), Erlend Tvinnereim (T), Michael Raschle (B), Werke von Mozart
# DJs Mister Pink, Mark Main, Mr. Pinks Keisha CD Release
# ROODIXX | Musik, Moderation, Entertainment
# Elizabeth, Daggers (B), Anodizer
# Aargauer Kantorei, Collegium Vocale Grossmünster, La Chapelle Ancienne, Dela Hüttner (S), Mirjam Blessing (A), Felix Rienth (T), Peter Mächler (B), Leitung: Kantor Daniel Schmid, Werke von Haydn
# Sing-A-Teh, Buju Gambis, Paous, DJs Simba Marara Family, Allycat Sound, Konzert mit anschliessender Party
# Ras Manuel (CR), DJs Rubb a dube Soundsystem, Ras Manuel, Irie Shottaz
# Honeyryder, Anker, Herz und weisses Kreuz
# Barbouze de Chez Fior, Annick Rody (vl), Camille Stoll (vl), Laurence Crevoisier (vl)
# My Name is George (CD-Taufe), The Weyers, We Love Machines
# Heidi Fries (Klar), Beat Fries (Trp), Bernhard Hörler (Org), Werke von Georg Böhm, Haydn, Bernhard Hörler u. a.
# DJ Lenardis, ab 21 Jahren
# DJ Rockit, Reve feat. Cliq Me
# DJ Kay Cut, DJs I-Scratch feat. MC Jay Jr & Friends
# Oliver Schnyder (Kl), Karl-Andreas Kolly (Kl), Werke von Bach, Beethoven, Brahms, Debussy, Holliger, Liszt, Lutoslawski, Mozart, Ravel
# District 5, Rhyth-Mix, King-Kong-kings, Woody Jam, Urban Revolution, Zeynep & Doris, Qualifikation
# Sottosole, Lino Mandato (voc), Claudio Stefanizzi (key), Tommy M. Tedesco (g), Marcello Staldini (b), Joe Molino (dr)
# Hipbone Slim & The Kneetremblers (GB), DJ El Tigre
# Kid Simius (D), Funkstep Brothers (D), The Architects, Bart
# DJs Dtp, Dada de Rien, Damjan G., we shall rise the same
# ...
# Piano Süd Trio, Antonello Messina (key), Luca Lo Bianco (b), Silvano Borzacchiello (dr)
# Collegium Novum Zürich, Peter Schweiger, Brice Pauset, Werke von Thomas Kessler, Brice Pauset, Steffen Schleiermacher, Sascha Janko Dragievi
# Werke von Gluck, Mozart, Nicolai, Weber, Puccini, in Zusammenarbeit mit der Dirigierklasse Johannes Schlaefli
# Deborah Rosenkranz (voc), Michael Schlierf (p)
# Vale Tudo, The Giving, Überyou, 10 Years Anniversary Bash
# I baroccoli, Kateryna Timokhina-Haupt (V), Stefanie Schlagenhauf (Fl), Pascal Suter (Fl), Helga Váradi (Cemb), Leitung: Massimiliano Matesic, Werke von Brescianello, Albinoni, Bach u. a.
# Am Kap & Donnie Darksome, Heiko
# DJs Tomstone, Skilly, Philly
# DJs Cochano, Benny B, Boombaztic, Don Juan
# Larissa Bretscher (v), Nicolas Stocker (dr, electr), Christian Wyss (key, g), Jeremias Keller (b)
# DJs Two-M, U.R.S, Sebastian
# Effie's Beast, Das Pferd, Matija
# DJs Melt, Raimondo P.,  Tomi
# Dieter Gröflin (voc), Peter Wicki  (g, voc), Sebastian Saraceno (dr), Toni Saraceno (b)
# DJ Laslow, ab 18 Jahren
# DJs Alex Dallas, John Doe
# DJs Urban Hands, Big Boys, Livin
# Dritte Wahl (D), Normahl (D), Feinwaschmittel
# Orchestre Musique des Lumières, Andrea Suter (S), Alessandra Boer (S), Anna Wall (Mezzo-S), Leitung: Facundo Agudin, Werke von Vivaldi, Händel, Palestrina
# XTR Human, Wavering Hands, DJ Pumuckel
# Jaël Akustiktrio feat. Vokalensemble Suppléments Musicaux, Jaël (voc), Cédric Monnier (key, kalimba), Domi Schreiber (g, voc)
# Lasse Siefert (T), Paulina Malanka (Kl), Yves Brühwiler (B), Sebastian Issler (Kl), Cassandre Stornetta (A), Akvile Sileikaite (Kl) u. a., Leitung: Brigitte Fassbaender (Mezzo-S)
# Vokalensemble Mariastein, Choralschola Mariastein, Christoph Kaufmann (Org), Leitung: Benedikt Rudolf von Rohr, Werke von Schubert, Bach, André, Benedikt Rudolf v. Rohr, Arvo Pärt, Pater Leo Stöcklin, Joseph Gabriel R
# Jugend Sinfonieorchester Zürich, Leitung: David Bruchez-Lalli
# DJ Kenjiro & Grimm, ab 21 Jahren
# DJs Pfund, Sweap, Gro, Certified
# DJs Lee van Dowski, Pasci, Igor, Captain Teis
# Two and Yuna, Chantal Krebs (voc, p, g, dr, electr), Luzian Graber (voc, p, g, dr, electr)
# Natalia Prishepenko & Annette Walther (V), Xandi van Dijk (Va), Thomas Schmitz (Vc), Werke von Haydn, L. van Dijk, Brahms
# Uniorchester Bern, Jazzorchester Universität Bern, Werke von Rimskij-Korsakov, Borodin, Harris, Silver, "Scheherajazz" ist ein von Skip Martin arrangiertes Werk für Big Band und Symphonieorchester und basiert auf der symphonischen Dichtung Scheherazade von Nikolaj Rimskij-Korsakov aus dem Jahr 1888.
# Crystal Castles (CAN), Guidance (USA)
# Casal Quartett, Felix Froschhammer (V), Rachel Späth (V), Markus Fleck (Va), Andreas Fleck (Vc), Werke von Schubert
# Musikkollegium Winterthur, Anu Komsi (S), Leitung: Heinz Holliger, Werke von Schubert, Ernst Krenek, Ravel u. a.
# Tonhalle-Orchester Zürich, Steven Isserlis (Vc), Leitung: Paavo Järvi, Werke von Sergei Prokofjew, Schumann, Einführung mit Lion Gallusser um 18.30 Uhr
# Iced Earth (USA), Ensiferum (FIN), Kataklysm, Unearth (SWE)
# Alessio Pianelli (Vc), Werke von Bach, Popper, Ysaÿe
# Christina Jaccard (voc), Daniel Pezzotti (cello), Andrea Wiesli (p)
# Trauffer, support: Vincent Gross
# DJs A-Train, Gro
# Japan Suicide (I), Cocaine Piss, Kataxnia
# 21st Century Symphony Orchestra, Leitung: Ernst van Tiel
# Sinfonieorchester Basel, Knabenkantorei Basel, Leitung: Markus Teutschbein
# Berner Symphonieorchester, Makoto Ozone (Kl), Leitung: Eiji Oue, Werke von Bernstein, Bernstein, Werkeinführung um 18.30 Uhr im Burgerratssaal
# Inhumate (F), Cremation, Gangrenomity
# Wucan, Hot Running Blood
# Djamanawak, support: Im Schilf
# Delacave (F), Venrte de Biche (F), Zad Kokar (F), After-Show: DJ Triple Alliance
# Concentus rivensis Orchester und Chor, Sarah Längle (S), Karl Jerolitsch (T), Samuel Zünd (Bar), Leitung: Enrico Lavarini, Werke von Enrico Lavarini
# Jaël, support: Marey, Jaël (voc, g, xylo), Cédric Monnier (p, mbira), Domi Schreiber (voc, g), Maryam Hammad (voc, g), Aurèle Louis (cello, b), Akustiktour
# Heidi Happy, Heidi Happy (voc), Ephrem Lüchinger (p), Christmas Tour
# Divine, Kissin Black
# I baroccoli, Kateryna Timokhina-Haupt (V), Stefanie Schlagenhauf (Fl), Pascal Suter (Fl), Helga Váradi (Cemb), Werke von Brescianello, Albinoni, Telemann u. a.
# Philharmonia Zürich, Okka von der Damerau (A), Leitung: Fabio Luisi, Werke von Schubert, Frank Martin, Einführung um 18.15 Uhr
# Tösstaler Kammerchor, Instrumentalensemble ad hoc, Leitung: Kantor Andreas Zwingli, Werke von Saint-Saens, Fauré, Franck
# Berliner Camerata, Gilad Karni (Va), Philippe Schartz (Trp), Theodisa Ntokou (Kl), Irina Pak (V), Olga Pak (V), Werke von Tschaikowski, Mozart, Telemann
# Collin Vallon Trio, Collin Vallon (key), Patrice Moret (b), Julian Sartorius (dr)
# Malcolm Braff (p), Laboratorium - Konzertreihe für frei improvisierte Musik
# Joke Lanz, Vincent Glanzmann, Joke Lanz (electr), Gerry Hemingway (perc), Vincent Glanzmann (perc)
# DJs Acee, A-Damn
# Swiss Jazz Orchestra, Rainer Tempel (comp,arr,dir)
# Christoph Stiefel, Christoph Stiefel (p), Ganesh Geymeier (sax, cl), Raphael Walser (b), Domi Chansorn (dr)
# Berührende Eigenkompositionen - melancholische und ironische Songs über Liebe, Hoffnung und die kleinen Enttäuschungen im Leben.
# Uzu, Ursula Bachmann (p, voc), Raphael Kalt (tp), Philipp Saner (g), Mischa Frey (b), Marcio de Sousa (dr), Tanja Zimmermann (voc)
# The Sad Pumpkins, Niculin Janett (voc, sax, cl), Noam Szyfer (g), Lukas Traxel (b), Maxime Paratte (dr)
# Tonhalle-Orchester Zürich, Zürcher Sing-Akademie, Rachel Frenkel (Mezzo-S), Jorge de León (T), Leitung: Omer Meir Wellber, Einstudierung: Andreas Felber, Werke von Ariel Ramírez, Leonard Bernstein, Einführung mit Rebekka Meyer um 18.30 Uhr
# The Fags, Scratch (A), Seemannsgarn, DJ X-Lingen-City-Rocker
# DJs DNO, Dizzy, Hugo R
# Leitung: Luiz Alves da Silva & Mathias Weibel, Werke von José Maurício Nunes Garcia
# DJs K-Rim, O-Kay, ab 21 Jahren
# Bams, Gety Gets, Mathematic
# DJs Marcus Gram, Wild Pich, Don Pepe, Christmas edition
# DJs Wood Nox & Eric Santana (NL), I-Scratch, Dany Rich, Bordy Dee, Mc B, Mc Jay Jr.
# DJs Metino (A), Crazy
# DJ Jay-K, ab 21 Jahren
# Sinfonia Ensemble, Leitung: Christof Escher, Neuvertonung von Armin Brunner, Stummfilm-Regie: Rudolf Dworsky & Rudolf Walther-Fein (1923)
# Fake Drake, Evelinn Trouble plays the songs of Drake
# DJs Sweep, Pfund 500
# Fusion Square Garden, Morò Mauro Corchia (voc, g), Mättu Urech (g), Dominique Montandon (key), Marcel Suk (b), Gianni Lanzilotti (dr), Roland Wäger (perc)
# Les Voda & Dave Phillips, DJ Member-Berries
# DJs Ecko, Spino, Robin Tune, ab 18 Jahren
# DJs Tomahawk, Selecta Iray, Rising Fyah, Jahcriss u.a.
# Live: Jose De Rico, Loco Escrito, ca. 40 DJs, Zimmer by Muevete & Pepe-J, Klub by Monkey Groove
# Sleeping Sun, Motörblast, 667, The Neighbour of the Beast, Sad, Living Theory
# Musikkollegium Winterthur, Laura Aikin (S), Leitung: Thomas Zehetmair (V), Werke von Schubert, Strauss (Sohn), J. Strauss, Lehár
# Jimi Jules, DJ Adrian Bergmann
# DJs Big Boys, Flexstreetboys, Curtis Bleu, Delakeyz, MDMO
# Karaoke Till Death (D), support: Walking with Ghosts, The Vicos
# Gregor Ehrsam (Org), Werke von Bach, Vierne, Gigout
# Luzerner Sinfonieorchester, Leitung: Steven Isserlis, Werke von Hummel, Boccherini, Bach u.a.
# Sinfonie Orchester Biel Solothurn, Christine Buffle (S), Niclas Oettermann (T), Leitung: Kaspar Zehnder, Werke von Strauss, Heuberger, Komzák, Neujahrskonzert
# Raw Vision, Christoph Grab (sax), Ronny Graupe (g), Thomas Lüscher (p, acc), Lukas Traxel (b), Maxime Paratte (dr)
# Volker Biesenbender, Die Werke für Violine solo von Bach und Paganini
# Live: Patricia Nora (ARG), mit literarischen Intermezzi und Schnupperkurs ab 19 Uhr
# Musikkollegium Winterthur, Mona Asuka (Kl), Leitung: Thomas Zehetmair, Werke von Wagner, Liszt, Beethoven
# Imperio (CD-Taufe), support: Deconvolution & No Kings No Slave
# Werke von Rinck, Dubois, Bach
# Pezzo Acoustic, DJ Metal Heart
# DJs Steve Supreme, Costa, Intresst, ab 21 Jahren, hosted by MC D Law
# DJs Theo, Jose Luis
# Duo Praxedis, Werke von Werke von T. Kirchner, A. Zimmerlin, Th. Bräm
# Möchtegang, support: Chris Bluemoon & Die Banausen
# The Boys You Know (A), OGMH
# DJs Mr. Ho (HKG), Manuel Fischer, Jimi Jules
# RHCP, Soul in motion, TPATC, 29 Pop Workshop, MissGrousiii, 29 and Beyond
# Otmar Musik St. Gallen, Maja Bösch (Org), Leitung: Stefan Christinger
# Tuliaisia, Marianne Racine-Granvik (voc), Vera Kappeler (org, p)
# Zeus (I), Zaperlipopette
# Florian Schneider, Sänger und Liederschreiber, mit Adam Taubitz, Meistergeiger
# Tonhalle-Orchester Zürich, Daniil Trifonov (Kl), Leitung: Kent Nagano, Werke von Beethoven, Olivier Messiaen, Einführung mit Ulrike Thiele um 16 Uhr
# Abendmusiken Basel, Miriam Feuersinger, Jan Börner, Gerd Türk, Markus Flaig, Leitung: Jörg-Andreas Bötticher, Werke von Lodovico Viadana
# Kammerton-Quartett, Mani Matter und Schweizer Volkslieder
# I Virtuosi di Milano, D. Moos (Kl, Moderation), E. Tanaka (S), E. Miletti (T), E. Kim (Bar), F. Rossi (Fl), G. Sanvito (Ob), C. Hauri (Vc), Leitung: Daniel Moos, Werke von Rossini, Donizetti, Puccini, Verdi u. a.
# DJs Laslow, MK, Leandro &amp; Co
# Teeth'n'Tongue (GR), DJs The Scorcher, Rootation
# Christina Brabetz (V), Nicolai Gerassimez (Kl), Werke von Joachim, Beethoven, Franck, Ravel
# Ensemble Anagamin Basel, Werke von Berio, Ravel, Giacinto Scelsi u. a.
# Sinfonieorchester Tifico, Cécile Grüebler (Vc),, Leitung: Christof Brunner
# Christoph Croisé (Vc), Oxana Shevchenko (Kl), Werke von Brahms, Paganini, Schubert, Rodion Schtschedrin
# Duo Praxedis, Werke von Bellini, Rossini, Thüring Bräm, Donizetti
# Orchester der Staatlichen Philharmonie Transilvania, Silke Gäng (Mezzo-S), Paul Sîrbu (V), Gabriel Gyarmati (Trp), Leitung: Giovanni Bria, Werke von Corelli, Torelli, Händel, Bach
# J.A. Bötticher (Cemb), J. Sprosse (p)
# Shorena Tsintsabadze (Kl), Werke von Chopin, Rachmaninoff, Scarlatti, Schumann, Skrjabin
# Simon Boss (g), Claudio Berger (b), Nici Struchen (dr)
# Vera Baumann (voc), Maximilian Möst (euph), Jérôme Müller (euph), Annina Schnyder (hr), Workshop-Konzerte Jazz
# Jugend-Sinfonieorchester Aargau, Alexander Boldachev (Harfe), Werke von Werner Wehrli, Reinhold Glière, Beethoven
# Stephan Urwyler, Stephan Urwyler (g, voc), Dä Det (p, hp), Daniel Schärer (b), Benjamin Schärer (dr)
# Nels1, Ma Gash, Zion Gate, Mathematic
# Arkona (PL), Batushka (PL), Black Messiah (D), Finntroll (FIN), Hedera
# Markus Schwenkreis (Org), Werke von Bach
# Kata Bucher, Tanja Dankner, Tobias Carshey u. a., Text: Daniel Rohr & Susanna Taverna
# Isaak (I), The Clamps (I)
# Trio Accanto, Markus Weiss (Sax), Nicolas Hodges (Kl), Christian Dierstein (Schlagz)
# Ace in Sleeve, DJ Höllehond
# Wiener Opernball Orchester, Elisabeth Flechl (S), Carsten Süss (T), Leitung: Andreas Spörri, Werke von Strauss, Kalman, Suppé, Moderation: Kilian Rosenberg
# Sol Gabetta (Vc), Hélène Grimaud (Kl), Werke von Schumann, Debussy, Brahms
# Elina Duni (voc, g, p, perc), Das Festival des jungen und aktuellen Schweizer Jazz
# Driving Force, Hair Dryer
# Basler Uni-Orchester, Leitung: Olga Pavlu, Werke von Mussorgski, Zoltán Kodály, Tchaikowski
# F.O.R.M., Ørefik
# Silverblue (Plattentaufe), Invivas, DJ Franky Stache
# Ronny Graupe's Spoom, Ronny Graupe (g), Jonas Westergaard (b), Christian Lillinger (dr), auch um 21.45 Uhr
# Film Hot Sugars Cold World (USA, 2015), live: J.G. Biberkopf, Dope Saint Jude, Dis Fig
# Dick Laurent, Pyrolyzed, Mantra
# Simon Baumann & Fabian Kalker, Simon Baumann (electr), Fabian Kalker (electr)
# DJs K-Rim, Pfund 500, Sweap, Big Boys, ab 20 Jahren, hosted by MC D Law
# Live: XV Kilist & Rocco, DJs Frisk & Index, Artemiss, M&D Babes, Alison
# DJs Certified, Croma, Curtis Bleu
# DJs Undreey, Force, Nightshift
# DJs Momo, Alex Terry
# Philharmonisches Kammerorchester Berlin, Leitung: Kirill Troussov (V), Werke von Vivaldi, Astor Piazzolla
# Berner Jubilate Chor, Bach Collegium Bern, Maria C. Schmid (S), Barbara Erni (A), Rolf Romei (T), Dominik Wörner (B), Leitung: Josef Zaugg, Werke von Mendelssohn Bartholdy
# Orchestra Filarmonica Della Fenice, Vesselina Kasarova (Mezzo-S),, Leitung: John Neschling, Werke von Gioacchino Rossini, Richard Wagner, Sergei Rachmaninow
# Urte Lucht (Cemb), Werke von Anglebert, Bach, Couperin u. a., Rezitation und Tanz: Stephan Mester
# Orchestra Filarmonica della Fenice, Vesselina Kasarova (Mezzo-S), Leitung: John Neschling, Werke von Rossini, R. Wagner, Rachmaninow
# Werke von Haydn, Ignaz Pleyel, Mozart
# Sarclo fait l'Dylan, Sarcloret (voc, g)
# Trio B.A.B & Hans Gysi, Alfred Zimmerlin (cello), Bruno Huwyler (dr), Birgit Hauser (voc), Texte von Hans Gysi
# Michel Wyss (voc), Ali Salvioni (perc), Mischa Podstransky (key)
# Die Singphoniker, Sinfonie Orchester Biel Solothurn, Stephanie Friede (S), Leitung: Lawrence Foster, Werke von Strauss, Haydn, 5. Sinfoniekonzert
# Luzerner Sinfonieorchester, Jana Bouskova (Harfe), Leitung: Pinchas Steinberg, Werke von Kabalewski, Glière, Tschaikowsky
# Sinfonieorchester Basel, Kian Soltani (Vc), Leitung: Simon Gaudenz, Werke von Dvorak, Mendelssohn
# Menic And The Bruncrana Firecrackers, Menic (voc), Jürg Frey (bjo, concertina, voc), David Brühlmann (acc), Tevfik Kujas (b)
# Gigi Moto, Gigi Moto (voc), JP von Dach (g)
# Kool Savas (D), Vega & Bosca (D)
# Nicole Johänntgen, Laurent Coulondre, Nicole Johänntgen (sax), René Mosele (tb), Jörgen Welander (tb), Laurent Coulondre (key), Lucas Saint (sax) u. a.
# Bülent Ceylan (DE), Raffi Lusso, Miguel M
# DJs Patric Pleasure, Ramon Ramones
# Julie Marghilano, Dana Ruh
# Jeanine De Bique, Soprano
# 10102

# %%
musicgraph_missing
# Out:
#        ambigous_result              genre  \
# 7                    0                NaN
# 10                   0                NaN
# 12                   0                NaN
# 13                   0                NaN
# 14                   0                NaN
# 16                   0                NaN
# 19                   0               Rock
# 21                   1  Electronica/Dance
# 22                   1                NaN
# 34                   0                NaN
# 38                   1                NaN
# 40                   0                NaN
# 45                   0                NaN
# 46                   0                NaN
# 47                   0               Rock
# 51                   0                NaN
# 55                   0                NaN
# 57                   0                NaN
# 64                   0                NaN
# 66                   0                NaN
# 68                   1  Electronica/Dance
# 70                   0                NaN
# 87                   0                NaN
# 107                  0                NaN
# 111                  0                NaN
# 112                  0                NaN
# 115                  0                NaN
# 116                  0                NaN
# 120                  0  Electronica/Dance
# 126                  0                NaN
# ...                ...                ...
# 61964                0                NaN
# 61965                0                NaN
# 61967                0                NaN
# 61968                0                NaN
# 61969                0                NaN
# 61970                0                NaN
# 61971                0                NaN
# 61973                0                NaN
# 61974                0                NaN
# 61975                1                NaN
# 61977                0                NaN
# 61978                0                NaN
# 61979                0                NaN
# 61980                0                NaN
# 61981                0                NaN
# 61982                0                NaN
# 61983                0                NaN
# 61984                0                NaN
# 61985                0                NaN
# 61986                0                NaN
# 61987                0                NaN
# 61988                0                NaN
# 61990                0                NaN
# 61991                0                NaN
# 61992                0                NaN
# 61993                0                NaN
# 61994                0                NaN
# 61995                0                NaN
# 61998                0                NaN
# 61999                0                NaN
#
#                                         name  no_result origin
# 7                                    St.Paul          1    NaN
# 10                                    Ondrej          1    NaN
# 12                                   Dubfunk          1    NaN
# 13                                 Everstone          1    NaN
# 14                               Massive Jay          1    NaN
# 16                                  Painhead          1    NaN
# 19                              Foo Fighters          1    NaN
# 21                                     Agnès          1    NaN
# 22                                   Storlon          1    NaN
# 34                                   Shahira          1    NaN
# 38                                 NORMANDIE          1    NaN
# 40                         BERTRAND BLESSING          1    NaN
# 45     INSTANT COMPOSER POOL ORCHESTRA / ICP          1    NaN
# 46                   MICHEL JONASZ (ABRAHAM)          1    NaN
# 47                      JULIETTE & THE LICKS          1    NaN
# 51                             Robbie Romero          1    NaN
# 55                                     LO JO          1    NaN
# 57                            MOUSS  & HAKIM          1    NaN
# 64                                 Matt Grey          1    NaN
# 66                              SIMON GERBER          1    NaN
# 68                                  Phonique          1    NaN
# 70                       NAPOLEON WASHINGTON          1    NaN
# 87                                 THERAPY ?          1    NaN
# 107                           ASHER SELECTOR          1    NaN
# 111                  JIMMY PAGE/ROBERT PLANT          1    NaN
# 112                  CHIC FEAT. NILE RODGERS          1    NaN
# 115               KLAUS DOLDINGER & PASSPORT          1    NaN
# 116                          BLACK EYED PEAS          1    NaN
# 120               CLAP YOUR HANDS SAY YEAH !          1    NaN
# 126               FERNANDO CORONA aka MURCOF          1    NaN
# ...                                      ...        ...    ...
# 61964            VolksSchlager Open Air 2017          1    NaN
# 61965                  Heitere Open Air 2017          1    NaN
# 61967                   Open Air Gampel 2017          1    NaN
# 61968                  Seaside Festival 2017          1    NaN
# 61969               SummerDays Festival 2017          1    NaN
# 61970                Riverside Festival 2017          1    NaN
# 61971               Riverside Festival 2017           1    NaN
# 61973                         Luke Mockridge          1    NaN
# 61974              Country Night Gstaad 2017          1    NaN
# 61975                            Tim Allhoff          1    NaN
# 61977                             Yokko 2017          1    NaN
# 61978             25 Jahre Marc Pircher 2017          1    NaN
# 61979                    das Palat Orchester          1    NaN
# 61980                Schupfart Festival 2017          1    NaN
# 61981                             Bliss 2017          1    NaN
# 61982                      Chippendales 2017          1    NaN
# 61983                   In Der Grossen Halle          1    NaN
# 61984               Stone Breeze - Tourdates          1    NaN
# 61985                             Chris Tall          1    NaN
# 61986           Kappeler Schlagernächte 2017          1    NaN
# 61987             ONE HEART Worship Day 2017          1    NaN
# 61988               Irish Folk Festival 2017          1    NaN
# 61990                SEAT Music Session 2017          1    NaN
# 61991                             Seven 2017          1    NaN
# 61992                          Schiller 2017          1    NaN
# 61993            Benefiz Schlager-Abend 2017          1    NaN
# 61994                   Johannes Oerding2017          1    NaN
# 61995                          Sonic 27 2017          1    NaN
# 61998                          Dwight Robson          1    NaN
# 61999              Original Ländlerweihnacht          1    NaN
#
# [31259 rows x 5 columns]
